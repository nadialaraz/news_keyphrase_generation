# %%
# !pip install fasttext
# !wget -q https://dl.fbaipublicfiles.com/fasttext/supervised-models/lid.176.bin
# Out:
# Requirement already satisfied: fasttext in /usr/local/lib/python3.11/dist-packages (0.9.3)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.11/dist-packages (from fasttext) (2.13.6)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from fasttext) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fasttext) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->fasttext) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->fasttext) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->fasttext) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->fasttext) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->fasttext) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->fasttext) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->fasttext) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->fasttext) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->fasttext) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->fasttext) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->fasttext) (2024.2.0)

# %%
import re
import os
import logging
import random
from collections import Counter
from datasets import load_dataset, DatasetDict
import fasttext

# ======================= KONFIGURASI =============================
OUTPUT_DIR = "/kaggle/working/One2Set/data"
SEED = 42
TRAIN_SAMPLE_SIZE = 30000
FASTTEXT_MODEL_PATH = "lid.176.bin"
# ================================================================

# Memuat model deteksi bahasa FastText
lang_model = fasttext.load_model(FASTTEXT_MODEL_PATH)

def is_english_fast(text):
    try:
        prediction = lang_model.predict(text.strip().replace('\n', ' '))[0][0]
        return prediction == '__label__en'
    except:
        return False

def clean_text(text):
    text = str(text).replace('\n', ' ').strip()
    text = re.sub(r'[^\x00-\x7F]+', '', text)  # Hapus karakter non-ASCII
    text = re.sub(r'\s+', ' ', text)
    return text

def replace_digits(text):
    return re.sub(r'\b\d+\b', '<digit>', text)

def tokenize(text):
    return text.lower().strip().split()

def preprocess_and_save():
    logging.getLogger("datasets").setLevel(logging.ERROR)

    # 1. Load & Sampling
    full_dataset = load_dataset("taln-ls2n/kptimes", trust_remote_code=True)
    train_sample = full_dataset['train'].shuffle(seed=SEED).select(range(TRAIN_SAMPLE_SIZE))

    # 2. Siapkan dataset akhir dengan split: train, valid, test
    dataset_sampled = DatasetDict({
        'train': train_sample,
        'valid': full_dataset['validation'],
        'test': full_dataset['test']
    })

    # 3. Buat direktori output
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    print(f"Menyimpan hasil ke: {OUTPUT_DIR}")

    # 4. Loop tiap split dan simpan .txt
    for split_name, dataset_split in dataset_sampled.items():
        src_path = os.path.join(OUTPUT_DIR, f"{split_name}_src.txt")
        trg_path = os.path.join(OUTPUT_DIR, f"{split_name}_trg.txt")

        total = 0
        dipakai = 0

        with open(src_path, 'w', encoding='utf-8') as f_src, \
             open(trg_path, 'w', encoding='utf-8') as f_trg:

            for example in dataset_split:
                total += 1
                title_raw = example['title']
                abstract_raw = example['abstract']

                if not is_english_fast(title_raw) or not is_english_fast(abstract_raw):
                    continue

                title = replace_digits(clean_text(title_raw))
                abstract = replace_digits(clean_text(abstract_raw))
                source_text = f"{title} <eos> {abstract}"

                MAX_TOKENS = 512
                tokens = source_text.split()
                if len(tokens) > MAX_TOKENS:
                    print(f"⚠ Truncated from {len(tokens)} to {MAX_TOKENS} tokens")
                    tokens = tokens[:MAX_TOKENS]
                source_text = ' '.join(tokens)

                f_src.write(source_text + '\n')

                # Proses target
                keyphrases = example['keyphrases']
                prmu = example['prmu']

                present_kps = []
                absent_kps = []

                for kp, p in zip(keyphrases, prmu):
                    if not is_english_fast(kp):
                        continue
                    kp_clean = replace_digits(clean_text(kp))
                    if kp_clean.strip() == '':
                        continue
                    if p.strip() == 'P':
                        present_kps.append(kp_clean)
                    else:
                        absent_kps.append(kp_clean)

                final_kps = []
                if present_kps:
                    final_kps.extend(present_kps)
                final_kps.append('<peos>')
                if absent_kps:
                    final_kps.extend(absent_kps)

                f_trg.write(';'.join(final_kps) + '\n')

                dipakai += 1

        print(f"Split '{split_name}' selesai: {dipakai}/{total} baris digunakan.")

    # 5. Tampilkan hasil akhir
    print("\nSemua file disimpan di:", OUTPUT_DIR)
    for fname in sorted(os.listdir(OUTPUT_DIR)):
        print(f" - {fname}")

if __name__ == "__main__":
    preprocess_and_save()
# Out:
# 📥 Memuat model deteksi bahasa FastText...
# 🚀 Memulai pra-pemrosesan KPTimes...
# 📥 Memuat dataset KPTimes dan mengambil sample...
# README.md:   0%|          | 0.00/3.37k [00:00<?, ?B/s]
# kptimes.py:   0%|          | 0.00/7.79k [00:00<?, ?B/s]
# test.jsonl:   0%|          | 0.00/84.7M [00:00<?, ?B/s]
# train.jsonl:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# dev.jsonl:   0%|          | 0.00/50.9M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# 📂 Menyimpan hasil ke: /kaggle/working/One2Set/data
# ⚠ Truncated from 1693 to 512 tokens
# ⚠ Truncated from 1928 to 512 tokens
# ⚠ Truncated from 628 to 512 tokens
# ⚠ Truncated from 890 to 512 tokens
# ⚠ Truncated from 519 to 512 tokens
# ⚠ Truncated from 792 to 512 tokens
# ⚠ Truncated from 881 to 512 tokens
# ⚠ Truncated from 906 to 512 tokens
# ⚠ Truncated from 828 to 512 tokens
# ⚠ Truncated from 712 to 512 tokens
# ⚠ Truncated from 815 to 512 tokens
# ⚠ Truncated from 1383 to 512 tokens
# ⚠ Truncated from 1335 to 512 tokens
# ⚠ Truncated from 814 to 512 tokens
# ⚠ Truncated from 797 to 512 tokens
# ⚠ Truncated from 1208 to 512 tokens
# ⚠ Truncated from 794 to 512 tokens
# ⚠ Truncated from 2198 to 512 tokens
# ⚠ Truncated from 1168 to 512 tokens
# ⚠ Truncated from 824 to 512 tokens
# ⚠ Truncated from 1006 to 512 tokens
# ⚠ Truncated from 5133 to 512 tokens
# ⚠ Truncated from 863 to 512 tokens
# ⚠ Truncated from 901 to 512 tokens
# ⚠ Truncated from 972 to 512 tokens
# ⚠ Truncated from 919 to 512 tokens
# ⚠ Truncated from 1024 to 512 tokens
# ⚠ Truncated from 1165 to 512 tokens
# ⚠ Truncated from 1926 to 512 tokens
# ⚠ Truncated from 1324 to 512 tokens
# ⚠ Truncated from 1314 to 512 tokens
# ⚠ Truncated from 727 to 512 tokens
# ⚠ Truncated from 619 to 512 tokens
# ⚠ Truncated from 906 to 512 tokens
# ⚠ Truncated from 1302 to 512 tokens
# ⚠ Truncated from 872 to 512 tokens
# ⚠ Truncated from 779 to 512 tokens
# ⚠ Truncated from 1157 to 512 tokens
# ⚠ Truncated from 961 to 512 tokens
# ⚠ Truncated from 808 to 512 tokens
# ⚠ Truncated from 1281 to 512 tokens
# ⚠ Truncated from 638 to 512 tokens
# ⚠ Truncated from 911 to 512 tokens
# ⚠ Truncated from 586 to 512 tokens
# ⚠ Truncated from 1178 to 512 tokens
# ⚠ Truncated from 926 to 512 tokens
# ⚠ Truncated from 2678 to 512 tokens
# ⚠ Truncated from 1244 to 512 tokens
# ⚠ Truncated from 571 to 512 tokens
# ⚠ Truncated from 2295 to 512 tokens
# ⚠ Truncated from 1125 to 512 tokens
# ⚠ Truncated from 815 to 512 tokens
# ⚠ Truncated from 619 to 512 tokens
# ⚠ Truncated from 1099 to 512 tokens
# ⚠ Truncated from 987 to 512 tokens
# ⚠ Truncated from 1013 to 512 tokens
# ⚠ Truncated from 1131 to 512 tokens
# ⚠ Truncated from 729 to 512 tokens
# ⚠ Truncated from 897 to 512 tokens
# ⚠ Truncated from 679 to 512 tokens
# ⚠ Truncated from 1245 to 512 tokens
# ⚠ Truncated from 530 to 512 tokens
# ⚠ Truncated from 1713 to 512 tokens
# ⚠ Truncated from 1306 to 512 tokens
# ⚠ Truncated from 952 to 512 tokens
# ⚠ Truncated from 690 to 512 tokens
# ⚠ Truncated from 1072 to 512 tokens
# ⚠ Truncated from 665 to 512 tokens
# ⚠ Truncated from 710 to 512 tokens
# ⚠ Truncated from 702 to 512 tokens
# ⚠ Truncated from 1255 to 512 tokens
# ⚠ Truncated from 882 to 512 tokens
# ⚠ Truncated from 888 to 512 tokens
# ⚠ Truncated from 757 to 512 tokens
# ⚠ Truncated from 846 to 512 tokens
# ⚠ Truncated from 1263 to 512 tokens
# ⚠ Truncated from 847 to 512 tokens
# ⚠ Truncated from 515 to 512 tokens
# ⚠ Truncated from 1147 to 512 tokens
# ⚠ Truncated from 740 to 512 tokens
# ⚠ Truncated from 903 to 512 tokens
# ⚠ Truncated from 879 to 512 tokens
# ⚠ Truncated from 869 to 512 tokens
# ⚠ Truncated from 1253 to 512 tokens
# ⚠ Truncated from 1419 to 512 tokens
# ⚠ Truncated from 585 to 512 tokens
# ⚠ Truncated from 3147 to 512 tokens
# ⚠ Truncated from 1142 to 512 tokens
# ⚠ Truncated from 696 to 512 tokens
# ⚠ Truncated from 1116 to 512 tokens
# ⚠ Truncated from 1291 to 512 tokens
# ⚠ Truncated from 650 to 512 tokens
# ⚠ Truncated from 788 to 512 tokens
# ⚠ Truncated from 861 to 512 tokens
# ⚠ Truncated from 785 to 512 tokens
# ⚠ Truncated from 1214 to 512 tokens
# ⚠ Truncated from 841 to 512 tokens
# ⚠ Truncated from 543 to 512 tokens
# ⚠ Truncated from 2209 to 512 tokens
# ⚠ Truncated from 1124 to 512 tokens
# ⚠ Truncated from 831 to 512 tokens
# ⚠ Truncated from 1282 to 512 tokens
# ⚠ Truncated from 1869 to 512 tokens
# ⚠ Truncated from 1283 to 512 tokens
# ⚠ Truncated from 695 to 512 tokens
# ⚠ Truncated from 624 to 512 tokens
# ⚠ Truncated from 1111 to 512 tokens
# ⚠ Truncated from 1727 to 512 tokens
# ⚠ Truncated from 919 to 512 tokens
# ⚠ Truncated from 1352 to 512 tokens
# ⚠ Truncated from 1160 to 512 tokens
# ⚠ Truncated from 1096 to 512 tokens
# ⚠ Truncated from 684 to 512 tokens
# ⚠ Truncated from 917 to 512 tokens
# ⚠ Truncated from 675 to 512 tokens
# ⚠ Truncated from 1124 to 512 tokens
# ⚠ Truncated from 970 to 512 tokens
# ⚠ Truncated from 1131 to 512 tokens
# ⚠ Truncated from 541 to 512 tokens
# ⚠ Truncated from 1127 to 512 tokens
# ⚠ Truncated from 638 to 512 tokens
# ⚠ Truncated from 739 to 512 tokens
# ⚠ Truncated from 813 to 512 tokens
# ⚠ Truncated from 740 to 512 tokens
# ⚠ Truncated from 709 to 512 tokens
# ⚠ Truncated from 1250 to 512 tokens
# ⚠ Truncated from 1301 to 512 tokens
# ⚠ Truncated from 1228 to 512 tokens
# ⚠ Truncated from 761 to 512 tokens
# ⚠ Truncated from 1361 to 512 tokens
# ⚠ Truncated from 1208 to 512 tokens
# ⚠ Truncated from 1559 to 512 tokens
# ⚠ Truncated from 1041 to 512 tokens
# ⚠ Truncated from 890 to 512 tokens
# ⚠ Truncated from 1385 to 512 tokens
# ⚠ Truncated from 1522 to 512 tokens
# ⚠ Truncated from 873 to 512 tokens
# ⚠ Truncated from 622 to 512 tokens
# ⚠ Truncated from 1184 to 512 tokens
# ⚠ Truncated from 521 to 512 tokens
# ⚠ Truncated from 800 to 512 tokens
# ⚠ Truncated from 1048 to 512 tokens
# ⚠ Truncated from 1710 to 512 tokens
# ⚠ Truncated from 889 to 512 tokens
# ⚠ Truncated from 628 to 512 tokens
# ⚠ Truncated from 834 to 512 tokens
# ⚠ Truncated from 747 to 512 tokens
# ⚠ Truncated from 1421 to 512 tokens
# ⚠ Truncated from 1176 to 512 tokens
# ⚠ Truncated from 909 to 512 tokens
# ⚠ Truncated from 1438 to 512 tokens
# ⚠ Truncated from 656 to 512 tokens
# ⚠ Truncated from 829 to 512 tokens
# ⚠ Truncated from 964 to 512 tokens
# ⚠ Truncated from 1434 to 512 tokens
# ⚠ Truncated from 2657 to 512 tokens
# ⚠ Truncated from 847 to 512 tokens
# ⚠ Truncated from 514 to 512 tokens
# ⚠ Truncated from 1025 to 512 tokens
# ⚠ Truncated from 577 to 512 tokens
# ⚠ Truncated from 743 to 512 tokens
# ⚠ Truncated from 1481 to 512 tokens
# ⚠ Truncated from 824 to 512 tokens
# ⚠ Truncated from 739 to 512 tokens
# ⚠ Truncated from 707 to 512 tokens
# ⚠ Truncated from 554 to 512 tokens
# ⚠ Truncated from 911 to 512 tokens
# ⚠ Truncated from 1105 to 512 tokens
# ⚠ Truncated from 855 to 512 tokens
# ⚠ Truncated from 1022 to 512 tokens
# ⚠ Truncated from 1315 to 512 tokens
# ⚠ Truncated from 1416 to 512 tokens
# ⚠ Truncated from 925 to 512 tokens
# ⚠ Truncated from 621 to 512 tokens
# ⚠ Truncated from 719 to 512 tokens
# ⚠ Truncated from 1000 to 512 tokens
# ⚠ Truncated from 705 to 512 tokens
# ⚠ Truncated from 728 to 512 tokens
# ⚠ Truncated from 1241 to 512 tokens
# ⚠ Truncated from 1074 to 512 tokens
# ⚠ Truncated from 630 to 512 tokens
# ⚠ Truncated from 1422 to 512 tokens
# ⚠ Truncated from 676 to 512 tokens
# ⚠ Truncated from 983 to 512 tokens
# ⚠ Truncated from 686 to 512 tokens
# ⚠ Truncated from 1051 to 512 tokens
# ⚠ Truncated from 993 to 512 tokens
# ⚠ Truncated from 964 to 512 tokens
# ⚠ Truncated from 574 to 512 tokens
# ⚠ Truncated from 1926 to 512 tokens
# ⚠ Truncated from 648 to 512 tokens
# ⚠ Truncated from 719 to 512 tokens
# ⚠ Truncated from 709 to 512 tokens
# ⚠ Truncated from 707 to 512 tokens
# ⚠ Truncated from 811 to 512 tokens
# ⚠ Truncated from 723 to 512 tokens
# ⚠ Truncated from 670 to 512 tokens
# ⚠ Truncated from 1074 to 512 tokens
# ⚠ Truncated from 682 to 512 tokens
# ⚠ Truncated from 868 to 512 tokens
# ⚠ Truncated from 1168 to 512 tokens
# ⚠ Truncated from 565 to 512 tokens
# ⚠ Truncated from 1437 to 512 tokens
# ⚠ Truncated from 1307 to 512 tokens
# ⚠ Truncated from 658 to 512 tokens
# ⚠ Truncated from 666 to 512 tokens
# ⚠ Truncated from 808 to 512 tokens
# ⚠ Truncated from 685 to 512 tokens
# ⚠ Truncated from 1325 to 512 tokens
# ⚠ Truncated from 1095 to 512 tokens
# ⚠ Truncated from 698 to 512 tokens
# ⚠ Truncated from 773 to 512 tokens
# ⚠ Truncated from 1184 to 512 tokens
# ⚠ Truncated from 897 to 512 tokens
# ⚠ Truncated from 1168 to 512 tokens
# ⚠ Truncated from 1248 to 512 tokens
# ⚠ Truncated from 549 to 512 tokens
# ⚠ Truncated from 616 to 512 tokens
# ⚠ Truncated from 1378 to 512 tokens
# ⚠ Truncated from 694 to 512 tokens
# ⚠ Truncated from 918 to 512 tokens
# ⚠ Truncated from 897 to 512 tokens
# ⚠ Truncated from 4438 to 512 tokens
# ⚠ Truncated from 591 to 512 tokens
# ⚠ Truncated from 1176 to 512 tokens
# ⚠ Truncated from 1076 to 512 tokens
# ⚠ Truncated from 621 to 512 tokens
# ⚠ Truncated from 694 to 512 tokens
# ⚠ Truncated from 995 to 512 tokens
# ⚠ Truncated from 1045 to 512 tokens
# ⚠ Truncated from 1151 to 512 tokens
# ⚠ Truncated from 793 to 512 tokens
# ⚠ Truncated from 668 to 512 tokens
# ⚠ Truncated from 1419 to 512 tokens
# ⚠ Truncated from 840 to 512 tokens
# ⚠ Truncated from 864 to 512 tokens
# ⚠ Truncated from 1240 to 512 tokens
# ⚠ Truncated from 865 to 512 tokens
# ⚠ Truncated from 906 to 512 tokens
# ⚠ Truncated from 691 to 512 tokens
# ⚠ Truncated from 1018 to 512 tokens
# ⚠ Truncated from 1083 to 512 tokens
# ⚠ Truncated from 797 to 512 tokens
# ⚠ Truncated from 712 to 512 tokens
# ⚠ Truncated from 893 to 512 tokens
# ⚠ Truncated from 665 to 512 tokens
# ⚠ Truncated from 1189 to 512 tokens
# ⚠ Truncated from 514 to 512 tokens
# ⚠ Truncated from 962 to 512 tokens
# ⚠ Truncated from 542 to 512 tokens
# ⚠ Truncated from 911 to 512 tokens
# ⚠ Truncated from 520 to 512 tokens
# ⚠ Truncated from 827 to 512 tokens
# ⚠ Truncated from 672 to 512 tokens
# ⚠ Truncated from 641 to 512 tokens
# ⚠ Truncated from 1279 to 512 tokens
# ⚠ Truncated from 4551 to 512 tokens
# ⚠ Truncated from 1398 to 512 tokens
# ⚠ Truncated from 1052 to 512 tokens
# ⚠ Truncated from 888 to 512 tokens
# ⚠ Truncated from 738 to 512 tokens
# ⚠ Truncated from 1055 to 512 tokens
# ⚠ Truncated from 856 to 512 tokens
# ⚠ Truncated from 1475 to 512 tokens
# ⚠ Truncated from 1103 to 512 tokens
# ⚠ Truncated from 561 to 512 tokens
# ⚠ Truncated from 1282 to 512 tokens
# ⚠ Truncated from 1044 to 512 tokens
# ⚠ Truncated from 1162 to 512 tokens
# ⚠ Truncated from 760 to 512 tokens
# ⚠ Truncated from 856 to 512 tokens
# ⚠ Truncated from 1042 to 512 tokens
# ⚠ Truncated from 1186 to 512 tokens
# ⚠ Truncated from 624 to 512 tokens
# ⚠ Truncated from 851 to 512 tokens
# ⚠ Truncated from 944 to 512 tokens
# ⚠ Truncated from 1050 to 512 tokens
# ⚠ Truncated from 998 to 512 tokens
# ⚠ Truncated from 1151 to 512 tokens
# ⚠ Truncated from 995 to 512 tokens
# ⚠ Truncated from 714 to 512 tokens
# ⚠ Truncated from 697 to 512 tokens
# ⚠ Truncated from 939 to 512 tokens
# ⚠ Truncated from 1426 to 512 tokens
# ⚠ Truncated from 956 to 512 tokens
# ⚠ Truncated from 1229 to 512 tokens
# ⚠ Truncated from 1097 to 512 tokens
# ⚠ Truncated from 596 to 512 tokens
# ⚠ Truncated from 981 to 512 tokens
# ⚠ Truncated from 1181 to 512 tokens
# ⚠ Truncated from 1460 to 512 tokens
# ⚠ Truncated from 1121 to 512 tokens
# ⚠ Truncated from 692 to 512 tokens
# ⚠ Truncated from 916 to 512 tokens
# ⚠ Truncated from 746 to 512 tokens
# ⚠ Truncated from 518 to 512 tokens
# ⚠ Truncated from 666 to 512 tokens
# ⚠ Truncated from 1230 to 512 tokens
# ⚠ Truncated from 526 to 512 tokens
# ⚠ Truncated from 1023 to 512 tokens
# ⚠ Truncated from 1059 to 512 tokens
# ⚠ Truncated from 826 to 512 tokens
# ⚠ Truncated from 551 to 512 tokens
# ⚠ Truncated from 866 to 512 tokens
# ⚠ Truncated from 623 to 512 tokens
# ⚠ Truncated from 884 to 512 tokens
# ⚠ Truncated from 1117 to 512 tokens
# ⚠ Truncated from 868 to 512 tokens
# ⚠ Truncated from 617 to 512 tokens
# ⚠ Truncated from 1084 to 512 tokens
# ⚠ Truncated from 1007 to 512 tokens
# ⚠ Truncated from 1118 to 512 tokens
# ⚠ Truncated from 1109 to 512 tokens
# ⚠ Truncated from 1339 to 512 tokens
# ⚠ Truncated from 1240 to 512 tokens
# ⚠ Truncated from 807 to 512 tokens
# ⚠ Truncated from 596 to 512 tokens
# ⚠ Truncated from 919 to 512 tokens
# ⚠ Truncated from 745 to 512 tokens
# ⚠ Truncated from 623 to 512 tokens
# ⚠ Truncated from 1419 to 512 tokens
# ⚠ Truncated from 1203 to 512 tokens
# ⚠ Truncated from 980 to 512 tokens
# ⚠ Truncated from 1517 to 512 tokens
# ⚠ Truncated from 733 to 512 tokens
# ⚠ Truncated from 1058 to 512 tokens
# ⚠ Truncated from 1785 to 512 tokens
# ⚠ Truncated from 667 to 512 tokens
# ⚠ Truncated from 598 to 512 tokens
# ⚠ Truncated from 851 to 512 tokens
# ⚠ Truncated from 969 to 512 tokens
# ⚠ Truncated from 655 to 512 tokens
# ⚠ Truncated from 1064 to 512 tokens
# ⚠ Truncated from 678 to 512 tokens
# ⚠ Truncated from 832 to 512 tokens
# ⚠ Truncated from 675 to 512 tokens
# ⚠ Truncated from 715 to 512 tokens
# ⚠ Truncated from 4737 to 512 tokens
# ⚠ Truncated from 1264 to 512 tokens
# ⚠ Truncated from 1124 to 512 tokens
# ⚠ Truncated from 733 to 512 tokens
# ⚠ Truncated from 544 to 512 tokens
# ⚠ Truncated from 1060 to 512 tokens
# ⚠ Truncated from 670 to 512 tokens
# ⚠ Truncated from 871 to 512 tokens
# ⚠ Truncated from 1383 to 512 tokens
# ⚠ Truncated from 910 to 512 tokens
# ⚠ Truncated from 999 to 512 tokens
# ⚠ Truncated from 1013 to 512 tokens
# ⚠ Truncated from 1076 to 512 tokens
# ⚠ Truncated from 824 to 512 tokens
# ⚠ Truncated from 867 to 512 tokens
# ⚠ Truncated from 751 to 512 tokens
# ⚠ Truncated from 1133 to 512 tokens
# ⚠ Truncated from 1141 to 512 tokens
# ⚠ Truncated from 765 to 512 tokens
# ⚠ Truncated from 825 to 512 tokens
# ⚠ Truncated from 596 to 512 tokens
# ⚠ Truncated from 581 to 512 tokens
# ⚠ Truncated from 855 to 512 tokens
# ⚠ Truncated from 2606 to 512 tokens
# ⚠ Truncated from 1088 to 512 tokens
# ⚠ Truncated from 1428 to 512 tokens
# ⚠ Truncated from 1117 to 512 tokens
# ⚠ Truncated from 1337 to 512 tokens
# ⚠ Truncated from 1160 to 512 tokens
# ⚠ Truncated from 1223 to 512 tokens
# ⚠ Truncated from 922 to 512 tokens
# ⚠ Truncated from 1444 to 512 tokens
# ⚠ Truncated from 1273 to 512 tokens
# ⚠ Truncated from 916 to 512 tokens
# ⚠ Truncated from 943 to 512 tokens
# ⚠ Truncated from 552 to 512 tokens
# ⚠ Truncated from 755 to 512 tokens
# ⚠ Truncated from 1362 to 512 tokens
# ⚠ Truncated from 616 to 512 tokens
# ⚠ Truncated from 984 to 512 tokens
# ⚠ Truncated from 581 to 512 tokens
# ⚠ Truncated from 516 to 512 tokens
# ⚠ Truncated from 1022 to 512 tokens
# ⚠ Truncated from 938 to 512 tokens
# ⚠ Truncated from 697 to 512 tokens
# ⚠ Truncated from 855 to 512 tokens
# ⚠ Truncated from 807 to 512 tokens
# ⚠ Truncated from 1065 to 512 tokens
# ⚠ Truncated from 563 to 512 tokens
# ⚠ Truncated from 980 to 512 tokens
# ⚠ Truncated from 833 to 512 tokens
# ⚠ Truncated from 1249 to 512 tokens
# ⚠ Truncated from 653 to 512 tokens
# ⚠ Truncated from 719 to 512 tokens
# ⚠ Truncated from 663 to 512 tokens
# ⚠ Truncated from 716 to 512 tokens
# ⚠ Truncated from 1045 to 512 tokens
# ⚠ Truncated from 1138 to 512 tokens
# ⚠ Truncated from 1137 to 512 tokens
# ⚠ Truncated from 1215 to 512 tokens
# ⚠ Truncated from 712 to 512 tokens
# ⚠ Truncated from 745 to 512 tokens
# ⚠ Truncated from 669 to 512 tokens
# ⚠ Truncated from 885 to 512 tokens
# ⚠ Truncated from 691 to 512 tokens
# ⚠ Truncated from 942 to 512 tokens
# ⚠ Truncated from 851 to 512 tokens
# ⚠ Truncated from 896 to 512 tokens
# ⚠ Truncated from 1303 to 512 tokens
# ⚠ Truncated from 719 to 512 tokens
# ⚠ Truncated from 746 to 512 tokens
# ⚠ Truncated from 938 to 512 tokens
# ⚠ Truncated from 775 to 512 tokens
# ⚠ Truncated from 664 to 512 tokens
# ⚠ Truncated from 630 to 512 tokens
# ⚠ Truncated from 750 to 512 tokens
# ⚠ Truncated from 730 to 512 tokens
# ⚠ Truncated from 1172 to 512 tokens
# ⚠ Truncated from 971 to 512 tokens
# ⚠ Truncated from 1380 to 512 tokens
# ⚠ Truncated from 1672 to 512 tokens
# ⚠ Truncated from 899 to 512 tokens
# ⚠ Truncated from 894 to 512 tokens
# ⚠ Truncated from 967 to 512 tokens
# ⚠ Truncated from 1662 to 512 tokens
# ⚠ Truncated from 995 to 512 tokens
# ⚠ Truncated from 1086 to 512 tokens
# ⚠ Truncated from 1046 to 512 tokens
# ⚠ Truncated from 756 to 512 tokens
# ⚠ Truncated from 844 to 512 tokens
# ⚠ Truncated from 787 to 512 tokens
# ⚠ Truncated from 752 to 512 tokens
# ⚠ Truncated from 748 to 512 tokens
# ⚠ Truncated from 1204 to 512 tokens
# ⚠ Truncated from 1051 to 512 tokens
# ⚠ Truncated from 685 to 512 tokens
# ⚠ Truncated from 936 to 512 tokens
# ⚠ Truncated from 896 to 512 tokens
# ⚠ Truncated from 889 to 512 tokens
# ⚠ Truncated from 781 to 512 tokens
# ⚠ Truncated from 1420 to 512 tokens
# ⚠ Truncated from 1232 to 512 tokens
# ⚠ Truncated from 936 to 512 tokens
# ⚠ Truncated from 1112 to 512 tokens
# ⚠ Truncated from 611 to 512 tokens
# ⚠ Truncated from 1113 to 512 tokens
# ⚠ Truncated from 1015 to 512 tokens
# ⚠ Truncated from 848 to 512 tokens
# ⚠ Truncated from 1392 to 512 tokens
# ⚠ Truncated from 579 to 512 tokens
# ⚠ Truncated from 1264 to 512 tokens
# ⚠ Truncated from 858 to 512 tokens
# ⚠ Truncated from 5215 to 512 tokens
# ⚠ Truncated from 1156 to 512 tokens
# ⚠ Truncated from 687 to 512 tokens
# ⚠ Truncated from 945 to 512 tokens
# ⚠ Truncated from 535 to 512 tokens
# ⚠ Truncated from 653 to 512 tokens
# ⚠ Truncated from 1346 to 512 tokens
# ⚠ Truncated from 1235 to 512 tokens
# ⚠ Truncated from 1204 to 512 tokens
# ⚠ Truncated from 685 to 512 tokens
# ⚠ Truncated from 709 to 512 tokens
# ⚠ Truncated from 2013 to 512 tokens
# ⚠ Truncated from 1094 to 512 tokens
# ⚠ Truncated from 1783 to 512 tokens
# ⚠ Truncated from 631 to 512 tokens
# ⚠ Truncated from 708 to 512 tokens
# ⚠ Truncated from 772 to 512 tokens
# ⚠ Truncated from 709 to 512 tokens
# ⚠ Truncated from 614 to 512 tokens
# ⚠ Truncated from 834 to 512 tokens
# ⚠ Truncated from 1245 to 512 tokens
# ⚠ Truncated from 760 to 512 tokens
# ⚠ Truncated from 891 to 512 tokens
# ⚠ Truncated from 1316 to 512 tokens
# ⚠ Truncated from 1292 to 512 tokens
# ⚠ Truncated from 1347 to 512 tokens
# ⚠ Truncated from 1065 to 512 tokens
# ⚠ Truncated from 963 to 512 tokens
# ⚠ Truncated from 875 to 512 tokens
# ⚠ Truncated from 941 to 512 tokens
# ⚠ Truncated from 1103 to 512 tokens
# ⚠ Truncated from 1452 to 512 tokens
# ⚠ Truncated from 885 to 512 tokens
# ⚠ Truncated from 943 to 512 tokens
# ⚠ Truncated from 990 to 512 tokens
# ⚠ Truncated from 678 to 512 tokens
# ⚠ Truncated from 680 to 512 tokens
# ⚠ Truncated from 1015 to 512 tokens
# ⚠ Truncated from 1036 to 512 tokens
# ⚠ Truncated from 1148 to 512 tokens
# ⚠ Truncated from 607 to 512 tokens
# ⚠ Truncated from 1299 to 512 tokens
# ⚠ Truncated from 1202 to 512 tokens
# ⚠ Truncated from 826 to 512 tokens
# ⚠ Truncated from 1227 to 512 tokens
# ⚠ Truncated from 577 to 512 tokens
# ⚠ Truncated from 1254 to 512 tokens
# ⚠ Truncated from 691 to 512 tokens
# ⚠ Truncated from 1095 to 512 tokens
# ⚠ Truncated from 540 to 512 tokens
# ⚠ Truncated from 1140 to 512 tokens
# ⚠ Truncated from 1318 to 512 tokens
# ⚠ Truncated from 1118 to 512 tokens
# ⚠ Truncated from 1042 to 512 tokens
# ⚠ Truncated from 664 to 512 tokens
# ⚠ Truncated from 908 to 512 tokens
# ⚠ Truncated from 1372 to 512 tokens
# ⚠ Truncated from 1035 to 512 tokens
# ⚠ Truncated from 863 to 512 tokens
# ⚠ Truncated from 995 to 512 tokens
# ⚠ Truncated from 721 to 512 tokens
# ⚠ Truncated from 566 to 512 tokens
# ⚠ Truncated from 823 to 512 tokens
# ⚠ Truncated from 1127 to 512 tokens
# ⚠ Truncated from 875 to 512 tokens
# ⚠ Truncated from 1302 to 512 tokens
# ⚠ Truncated from 1044 to 512 tokens
# ⚠ Truncated from 721 to 512 tokens
# ⚠ Truncated from 1045 to 512 tokens
# ⚠ Truncated from 884 to 512 tokens
# ⚠ Truncated from 693 to 512 tokens
# ⚠ Truncated from 792 to 512 tokens
# ⚠ Truncated from 1068 to 512 tokens
# ⚠ Truncated from 1158 to 512 tokens
# ⚠ Truncated from 595 to 512 tokens
# ⚠ Truncated from 1322 to 512 tokens
# ⚠ Truncated from 1281 to 512 tokens
# ⚠ Truncated from 1582 to 512 tokens
# ⚠ Truncated from 873 to 512 tokens
# ⚠ Truncated from 775 to 512 tokens
# ⚠ Truncated from 881 to 512 tokens
# ⚠ Truncated from 1194 to 512 tokens
# ⚠ Truncated from 887 to 512 tokens
# ⚠ Truncated from 728 to 512 tokens
# ⚠ Truncated from 1456 to 512 tokens
# ⚠ Truncated from 547 to 512 tokens
# ⚠ Truncated from 838 to 512 tokens
# ⚠ Truncated from 1038 to 512 tokens
# ⚠ Truncated from 1150 to 512 tokens
# ⚠ Truncated from 828 to 512 tokens
# ⚠ Truncated from 678 to 512 tokens
# ⚠ Truncated from 644 to 512 tokens
# ⚠ Truncated from 1581 to 512 tokens
# ⚠ Truncated from 1102 to 512 tokens
# ⚠ Truncated from 716 to 512 tokens
# ⚠ Truncated from 752 to 512 tokens
# ⚠ Truncated from 542 to 512 tokens
# ⚠ Truncated from 822 to 512 tokens
# ⚠ Truncated from 1101 to 512 tokens
# ⚠ Truncated from 908 to 512 tokens
# ⚠ Truncated from 845 to 512 tokens
# ⚠ Truncated from 513 to 512 tokens
# ⚠ Truncated from 1284 to 512 tokens
# ⚠ Truncated from 934 to 512 tokens
# ⚠ Truncated from 1377 to 512 tokens
# ⚠ Truncated from 1284 to 512 tokens
# ⚠ Truncated from 749 to 512 tokens
# ⚠ Truncated from 1033 to 512 tokens
# ⚠ Truncated from 536 to 512 tokens
# ⚠ Truncated from 974 to 512 tokens
# ⚠ Truncated from 1137 to 512 tokens
# ⚠ Truncated from 1136 to 512 tokens
# ⚠ Truncated from 851 to 512 tokens
# ⚠ Truncated from 1131 to 512 tokens
# ⚠ Truncated from 531 to 512 tokens
# ⚠ Truncated from 1132 to 512 tokens
# ⚠ Truncated from 964 to 512 tokens
# ⚠ Truncated from 664 to 512 tokens
# ⚠ Truncated from 780 to 512 tokens
# ⚠ Truncated from 1246 to 512 tokens
# ⚠ Truncated from 2148 to 512 tokens
# ⚠ Truncated from 987 to 512 tokens
# ⚠ Truncated from 848 to 512 tokens
# ⚠ Truncated from 1345 to 512 tokens
# ⚠ Truncated from 1224 to 512 tokens
# ⚠ Truncated from 588 to 512 tokens
# ⚠ Truncated from 1289 to 512 tokens
# ⚠ Truncated from 687 to 512 tokens
# ⚠ Truncated from 1061 to 512 tokens
# ⚠ Truncated from 1197 to 512 tokens
# ⚠ Truncated from 1217 to 512 tokens
# ⚠ Truncated from 1209 to 512 tokens
# ⚠ Truncated from 862 to 512 tokens
# ⚠ Truncated from 560 to 512 tokens
# ⚠ Truncated from 840 to 512 tokens
# ⚠ Truncated from 1521 to 512 tokens
# ⚠ Truncated from 772 to 512 tokens
# ⚠ Truncated from 1101 to 512 tokens
# ⚠ Truncated from 559 to 512 tokens
# ⚠ Truncated from 843 to 512 tokens
# ⚠ Truncated from 602 to 512 tokens
# ⚠ Truncated from 649 to 512 tokens
# ⚠ Truncated from 582 to 512 tokens
# ⚠ Truncated from 1454 to 512 tokens
# ⚠ Truncated from 962 to 512 tokens
# ⚠ Truncated from 628 to 512 tokens
# ⚠ Truncated from 952 to 512 tokens
# ⚠ Truncated from 941 to 512 tokens
# ⚠ Truncated from 1018 to 512 tokens
# ⚠ Truncated from 860 to 512 tokens
# ⚠ Truncated from 616 to 512 tokens
# ⚠ Truncated from 669 to 512 tokens
# ⚠ Truncated from 871 to 512 tokens
# ⚠ Truncated from 1354 to 512 tokens
# ⚠ Truncated from 799 to 512 tokens
# ⚠ Truncated from 1427 to 512 tokens
# ⚠ Truncated from 1233 to 512 tokens
# ⚠ Truncated from 1229 to 512 tokens
# ⚠ Truncated from 1218 to 512 tokens
# ⚠ Truncated from 617 to 512 tokens
# ⚠ Truncated from 663 to 512 tokens
# ⚠ Truncated from 1976 to 512 tokens
# ⚠ Truncated from 1165 to 512 tokens
# ⚠ Truncated from 606 to 512 tokens
# ⚠ Truncated from 1166 to 512 tokens
# ⚠ Truncated from 1247 to 512 tokens
# ⚠ Truncated from 876 to 512 tokens
# ⚠ Truncated from 802 to 512 tokens
# ⚠ Truncated from 1287 to 512 tokens
# ⚠ Truncated from 1325 to 512 tokens
# ⚠ Truncated from 801 to 512 tokens
# ⚠ Truncated from 575 to 512 tokens
# ⚠ Truncated from 642 to 512 tokens
# ⚠ Truncated from 771 to 512 tokens
# ⚠ Truncated from 1171 to 512 tokens
# ⚠ Truncated from 1065 to 512 tokens
# ⚠ Truncated from 636 to 512 tokens
# ⚠ Truncated from 579 to 512 tokens
# ⚠ Truncated from 840 to 512 tokens
# ⚠ Truncated from 1238 to 512 tokens
# ⚠ Truncated from 1046 to 512 tokens
# ⚠ Truncated from 577 to 512 tokens
# ⚠ Truncated from 963 to 512 tokens
# ⚠ Truncated from 514 to 512 tokens
# ⚠ Truncated from 725 to 512 tokens
# ⚠ Truncated from 1703 to 512 tokens
# ⚠ Truncated from 1482 to 512 tokens
# ⚠ Truncated from 822 to 512 tokens
# ⚠ Truncated from 819 to 512 tokens
# ⚠ Truncated from 1289 to 512 tokens
# ⚠ Truncated from 738 to 512 tokens
# ⚠ Truncated from 1372 to 512 tokens
# ⚠ Truncated from 732 to 512 tokens
# ⚠ Truncated from 1027 to 512 tokens
# ⚠ Truncated from 773 to 512 tokens
# ⚠ Truncated from 1701 to 512 tokens
# ⚠ Truncated from 787 to 512 tokens
# ⚠ Truncated from 690 to 512 tokens
# ⚠ Truncated from 634 to 512 tokens
# ⚠ Truncated from 1112 to 512 tokens
# ⚠ Truncated from 1139 to 512 tokens
# ⚠ Truncated from 1139 to 512 tokens
# ⚠ Truncated from 905 to 512 tokens
# ⚠ Truncated from 1069 to 512 tokens
# ⚠ Truncated from 767 to 512 tokens
# ⚠ Truncated from 693 to 512 tokens
# ⚠ Truncated from 1608 to 512 tokens
# ⚠ Truncated from 697 to 512 tokens
# ⚠ Truncated from 1170 to 512 tokens
# ⚠ Truncated from 613 to 512 tokens
# ⚠ Truncated from 773 to 512 tokens
# ⚠ Truncated from 653 to 512 tokens
# ⚠ Truncated from 674 to 512 tokens
# ⚠ Truncated from 894 to 512 tokens
# ⚠ Truncated from 916 to 512 tokens
# ⚠ Truncated from 1060 to 512 tokens
# ⚠ Truncated from 746 to 512 tokens
# ⚠ Truncated from 709 to 512 tokens
# ⚠ Truncated from 781 to 512 tokens
# ⚠ Truncated from 785 to 512 tokens
# ⚠ Truncated from 872 to 512 tokens
# ⚠ Truncated from 986 to 512 tokens
# ⚠ Truncated from 1241 to 512 tokens
# ⚠ Truncated from 996 to 512 tokens
# ⚠ Truncated from 1061 to 512 tokens
# ⚠ Truncated from 1257 to 512 tokens
# ⚠ Truncated from 888 to 512 tokens
# ⚠ Truncated from 795 to 512 tokens
# ⚠ Truncated from 1343 to 512 tokens
# ⚠ Truncated from 924 to 512 tokens
# ⚠ Truncated from 1624 to 512 tokens
# ⚠ Truncated from 772 to 512 tokens
# ⚠ Truncated from 733 to 512 tokens
# ⚠ Truncated from 980 to 512 tokens
# ⚠ Truncated from 608 to 512 tokens
# ⚠ Truncated from 636 to 512 tokens
# ⚠ Truncated from 1187 to 512 tokens
# ⚠ Truncated from 633 to 512 tokens
# ⚠ Truncated from 677 to 512 tokens
# ⚠ Truncated from 514 to 512 tokens
# ⚠ Truncated from 589 to 512 tokens
# ⚠ Truncated from 1238 to 512 tokens
# ⚠ Truncated from 1051 to 512 tokens
# ⚠ Truncated from 1114 to 512 tokens
# ⚠ Truncated from 727 to 512 tokens
# ⚠ Truncated from 517 to 512 tokens
# ⚠ Truncated from 872 to 512 tokens
# ⚠ Truncated from 662 to 512 tokens
# ⚠ Truncated from 843 to 512 tokens
# ⚠ Truncated from 801 to 512 tokens
# ⚠ Truncated from 1093 to 512 tokens
# ⚠ Truncated from 546 to 512 tokens
# ⚠ Truncated from 766 to 512 tokens
# ⚠ Truncated from 968 to 512 tokens
# ⚠ Truncated from 800 to 512 tokens
# ⚠ Truncated from 695 to 512 tokens
# ⚠ Truncated from 1547 to 512 tokens
# ⚠ Truncated from 562 to 512 tokens
# ⚠ Truncated from 1098 to 512 tokens
# ⚠ Truncated from 1059 to 512 tokens
# ⚠ Truncated from 1076 to 512 tokens
# ⚠ Truncated from 828 to 512 tokens
# ⚠ Truncated from 891 to 512 tokens
# ⚠ Truncated from 1513 to 512 tokens
# ⚠ Truncated from 908 to 512 tokens
# ⚠ Truncated from 675 to 512 tokens
# ⚠ Truncated from 2564 to 512 tokens
# ⚠ Truncated from 682 to 512 tokens
# ⚠ Truncated from 779 to 512 tokens
# ⚠ Truncated from 716 to 512 tokens
# ⚠ Truncated from 587 to 512 tokens
# ⚠ Truncated from 851 to 512 tokens
# ⚠ Truncated from 1124 to 512 tokens
# ⚠ Truncated from 958 to 512 tokens
# ⚠ Truncated from 901 to 512 tokens
# ⚠ Truncated from 1244 to 512 tokens
# ⚠ Truncated from 630 to 512 tokens
# ⚠ Truncated from 965 to 512 tokens
# ⚠ Truncated from 1254 to 512 tokens
# ⚠ Truncated from 641 to 512 tokens
# ⚠ Truncated from 1108 to 512 tokens
# ⚠ Truncated from 585 to 512 tokens
# ⚠ Truncated from 1519 to 512 tokens
# ⚠ Truncated from 761 to 512 tokens
# ⚠ Truncated from 1209 to 512 tokens
# ⚠ Truncated from 715 to 512 tokens
# ⚠ Truncated from 1029 to 512 tokens
# ⚠ Truncated from 1141 to 512 tokens
# ⚠ Truncated from 526 to 512 tokens
# ⚠ Truncated from 1402 to 512 tokens
# ⚠ Truncated from 1542 to 512 tokens
# ⚠ Truncated from 951 to 512 tokens
# ⚠ Truncated from 620 to 512 tokens
# ⚠ Truncated from 1295 to 512 tokens
# ⚠ Truncated from 739 to 512 tokens
# ⚠ Truncated from 1036 to 512 tokens
# ⚠ Truncated from 1090 to 512 tokens
# ⚠ Truncated from 1374 to 512 tokens
# ⚠ Truncated from 1190 to 512 tokens
# ⚠ Truncated from 1101 to 512 tokens
# ⚠ Truncated from 1101 to 512 tokens
# ⚠ Truncated from 1070 to 512 tokens
# ⚠ Truncated from 891 to 512 tokens
# ⚠ Truncated from 564 to 512 tokens
# ⚠ Truncated from 1655 to 512 tokens
# ⚠ Truncated from 564 to 512 tokens
# ⚠ Truncated from 664 to 512 tokens
# ⚠ Truncated from 1137 to 512 tokens
# ⚠ Truncated from 3012 to 512 tokens
# ⚠ Truncated from 1070 to 512 tokens
# ⚠ Truncated from 1572 to 512 tokens
# ⚠ Truncated from 1094 to 512 tokens
# ⚠ Truncated from 1189 to 512 tokens
# ⚠ Truncated from 1062 to 512 tokens
# ⚠ Truncated from 871 to 512 tokens
# ⚠ Truncated from 1416 to 512 tokens
# ⚠ Truncated from 1479 to 512 tokens
# ⚠ Truncated from 895 to 512 tokens
# ⚠ Truncated from 619 to 512 tokens
# ⚠ Truncated from 1206 to 512 tokens
# ⚠ Truncated from 634 to 512 tokens
# ⚠ Truncated from 877 to 512 tokens
# ⚠ Truncated from 1105 to 512 tokens
# ⚠ Truncated from 1391 to 512 tokens
# ⚠ Truncated from 748 to 512 tokens
# ⚠ Truncated from 601 to 512 tokens
# ⚠ Truncated from 524 to 512 tokens
# ⚠ Truncated from 704 to 512 tokens
# ⚠ Truncated from 836 to 512 tokens
# ⚠ Truncated from 948 to 512 tokens
# ⚠ Truncated from 622 to 512 tokens
# ⚠ Truncated from 1086 to 512 tokens
# ⚠ Truncated from 1215 to 512 tokens
# ⚠ Truncated from 973 to 512 tokens
# ⚠ Truncated from 1014 to 512 tokens
# ⚠ Truncated from 1167 to 512 tokens
# ⚠ Truncated from 937 to 512 tokens
# ⚠ Truncated from 1066 to 512 tokens
# ⚠ Truncated from 837 to 512 tokens
# ⚠ Truncated from 667 to 512 tokens
# ⚠ Truncated from 1307 to 512 tokens
# ⚠ Truncated from 618 to 512 tokens
# ⚠ Truncated from 593 to 512 tokens
# ⚠ Truncated from 793 to 512 tokens
# ⚠ Truncated from 3311 to 512 tokens
# ⚠ Truncated from 836 to 512 tokens
# ⚠ Truncated from 703 to 512 tokens
# ⚠ Truncated from 1061 to 512 tokens
# ⚠ Truncated from 880 to 512 tokens
# ⚠ Truncated from 862 to 512 tokens
# ⚠ Truncated from 1574 to 512 tokens
# ⚠ Truncated from 854 to 512 tokens
# ⚠ Truncated from 1189 to 512 tokens
# ⚠ Truncated from 1150 to 512 tokens
# ⚠ Truncated from 1041 to 512 tokens
# ⚠ Truncated from 1252 to 512 tokens
# ⚠ Truncated from 1236 to 512 tokens
# ⚠ Truncated from 566 to 512 tokens
# ⚠ Truncated from 1620 to 512 tokens
# ⚠ Truncated from 1610 to 512 tokens
# ⚠ Truncated from 569 to 512 tokens
# ⚠ Truncated from 542 to 512 tokens
# ⚠ Truncated from 1252 to 512 tokens
# ⚠ Truncated from 805 to 512 tokens
# ⚠ Truncated from 732 to 512 tokens
# ⚠ Truncated from 1088 to 512 tokens
# ⚠ Truncated from 1314 to 512 tokens
# ⚠ Truncated from 735 to 512 tokens
# ⚠ Truncated from 852 to 512 tokens
# ⚠ Truncated from 1229 to 512 tokens
# ⚠ Truncated from 1314 to 512 tokens
# ⚠ Truncated from 1408 to 512 tokens
# ⚠ Truncated from 966 to 512 tokens
# ⚠ Truncated from 563 to 512 tokens
# ⚠ Truncated from 779 to 512 tokens
# ⚠ Truncated from 1494 to 512 tokens
# ⚠ Truncated from 1142 to 512 tokens
# ⚠ Truncated from 1402 to 512 tokens
# ⚠ Truncated from 658 to 512 tokens
# ⚠ Truncated from 777 to 512 tokens
# ⚠ Truncated from 2015 to 512 tokens
# ⚠ Truncated from 863 to 512 tokens
# ⚠ Truncated from 576 to 512 tokens
# ⚠ Truncated from 721 to 512 tokens
# ⚠ Truncated from 766 to 512 tokens
# ⚠ Truncated from 731 to 512 tokens
# ⚠ Truncated from 1078 to 512 tokens
# ⚠ Truncated from 881 to 512 tokens
# ⚠ Truncated from 743 to 512 tokens
# ⚠ Truncated from 875 to 512 tokens
# ⚠ Truncated from 675 to 512 tokens
# ⚠ Truncated from 806 to 512 tokens
# ⚠ Truncated from 1135 to 512 tokens
# ⚠ Truncated from 1315 to 512 tokens
# ⚠ Truncated from 968 to 512 tokens
# ⚠ Truncated from 964 to 512 tokens
# ⚠ Truncated from 844 to 512 tokens
# ⚠ Truncated from 661 to 512 tokens
# ⚠ Truncated from 1166 to 512 tokens
# ⚠ Truncated from 1656 to 512 tokens
# ⚠ Truncated from 939 to 512 tokens
# ⚠ Truncated from 740 to 512 tokens
# ⚠ Truncated from 563 to 512 tokens
# ⚠ Truncated from 706 to 512 tokens
# ⚠ Truncated from 1438 to 512 tokens
# ⚠ Truncated from 715 to 512 tokens
# ⚠ Truncated from 544 to 512 tokens
# ⚠ Truncated from 1012 to 512 tokens
# ⚠ Truncated from 784 to 512 tokens
# ⚠ Truncated from 1270 to 512 tokens
# ⚠ Truncated from 691 to 512 tokens
# ⚠ Truncated from 967 to 512 tokens
# ⚠ Truncated from 585 to 512 tokens
# ⚠ Truncated from 896 to 512 tokens
# ⚠ Truncated from 806 to 512 tokens
# ⚠ Truncated from 1053 to 512 tokens
# ⚠ Truncated from 1077 to 512 tokens
# ⚠ Truncated from 1253 to 512 tokens
# ⚠ Truncated from 1021 to 512 tokens
# ⚠ Truncated from 1008 to 512 tokens
# ⚠ Truncated from 967 to 512 tokens
# ⚠ Truncated from 1246 to 512 tokens
# ⚠ Truncated from 1069 to 512 tokens
# ⚠ Truncated from 595 to 512 tokens
# ⚠ Truncated from 826 to 512 tokens
# ⚠ Truncated from 701 to 512 tokens
# ⚠ Truncated from 1092 to 512 tokens
# ⚠ Truncated from 1107 to 512 tokens
# ⚠ Truncated from 829 to 512 tokens
# ⚠ Truncated from 791 to 512 tokens
# ⚠ Truncated from 716 to 512 tokens
# ⚠ Truncated from 857 to 512 tokens
# ⚠ Truncated from 1207 to 512 tokens
# ⚠ Truncated from 965 to 512 tokens
# ⚠ Truncated from 1313 to 512 tokens
# ⚠ Truncated from 987 to 512 tokens
# ⚠ Truncated from 878 to 512 tokens
# ⚠ Truncated from 1855 to 512 tokens
# ⚠ Truncated from 855 to 512 tokens
# ⚠ Truncated from 1307 to 512 tokens
# ⚠ Truncated from 1245 to 512 tokens
# ⚠ Truncated from 988 to 512 tokens
# ⚠ Truncated from 1216 to 512 tokens
# ⚠ Truncated from 1564 to 512 tokens
# ⚠ Truncated from 825 to 512 tokens
# ⚠ Truncated from 860 to 512 tokens
# ⚠ Truncated from 1148 to 512 tokens
# ⚠ Truncated from 1352 to 512 tokens
# ⚠ Truncated from 994 to 512 tokens
# ⚠ Truncated from 1629 to 512 tokens
# ⚠ Truncated from 1294 to 512 tokens
# ⚠ Truncated from 909 to 512 tokens
# ⚠ Truncated from 699 to 512 tokens
# ⚠ Truncated from 1380 to 512 tokens
# ⚠ Truncated from 784 to 512 tokens
# ⚠ Truncated from 776 to 512 tokens
# ⚠ Truncated from 1125 to 512 tokens
# ⚠ Truncated from 1312 to 512 tokens
# ⚠ Truncated from 864 to 512 tokens
# ⚠ Truncated from 873 to 512 tokens
# ⚠ Truncated from 2164 to 512 tokens
# ⚠ Truncated from 1224 to 512 tokens
# ⚠ Truncated from 1118 to 512 tokens
# ⚠ Truncated from 791 to 512 tokens
# ⚠ Truncated from 685 to 512 tokens
# ⚠ Truncated from 631 to 512 tokens
# ⚠ Truncated from 822 to 512 tokens
# ⚠ Truncated from 757 to 512 tokens
# ⚠ Truncated from 653 to 512 tokens
# ⚠ Truncated from 1149 to 512 tokens
# ⚠ Truncated from 1296 to 512 tokens
# ⚠ Truncated from 545 to 512 tokens
# ⚠ Truncated from 1082 to 512 tokens
# ⚠ Truncated from 1190 to 512 tokens
# ⚠ Truncated from 1223 to 512 tokens
# ⚠ Truncated from 977 to 512 tokens
# ⚠ Truncated from 1168 to 512 tokens
# ⚠ Truncated from 1645 to 512 tokens
# ⚠ Truncated from 761 to 512 tokens
# ⚠ Truncated from 585 to 512 tokens
# ⚠ Truncated from 710 to 512 tokens
# ⚠ Truncated from 748 to 512 tokens
# ⚠ Truncated from 989 to 512 tokens
# ⚠ Truncated from 915 to 512 tokens
# ⚠ Truncated from 979 to 512 tokens
# ⚠ Truncated from 827 to 512 tokens
# ⚠ Truncated from 859 to 512 tokens
# ⚠ Truncated from 663 to 512 tokens
# ⚠ Truncated from 1542 to 512 tokens
# ⚠ Truncated from 991 to 512 tokens
# ⚠ Truncated from 1092 to 512 tokens
# ⚠ Truncated from 1003 to 512 tokens
# ⚠ Truncated from 828 to 512 tokens
# ⚠ Truncated from 699 to 512 tokens
# ⚠ Truncated from 2061 to 512 tokens
# ⚠ Truncated from 1001 to 512 tokens
# ⚠ Truncated from 734 to 512 tokens
# ⚠ Truncated from 1058 to 512 tokens
# ⚠ Truncated from 847 to 512 tokens
# ⚠ Truncated from 987 to 512 tokens
# ⚠ Truncated from 746 to 512 tokens
# ⚠ Truncated from 667 to 512 tokens
# ⚠ Truncated from 1243 to 512 tokens
# ⚠ Truncated from 832 to 512 tokens
# ⚠ Truncated from 2498 to 512 tokens
# ⚠ Truncated from 581 to 512 tokens
# ⚠ Truncated from 593 to 512 tokens
# ⚠ Truncated from 1166 to 512 tokens
# ⚠ Truncated from 878 to 512 tokens
# ⚠ Truncated from 1722 to 512 tokens
# ⚠ Truncated from 996 to 512 tokens
# ⚠ Truncated from 1349 to 512 tokens
# ⚠ Truncated from 812 to 512 tokens
# ⚠ Truncated from 887 to 512 tokens
# ⚠ Truncated from 561 to 512 tokens
# ⚠ Truncated from 1052 to 512 tokens
# ⚠ Truncated from 2876 to 512 tokens
# ⚠ Truncated from 709 to 512 tokens
# ⚠ Truncated from 600 to 512 tokens
# ⚠ Truncated from 625 to 512 tokens
# ⚠ Truncated from 1148 to 512 tokens
# ⚠ Truncated from 1287 to 512 tokens
# ⚠ Truncated from 871 to 512 tokens
# ⚠ Truncated from 1101 to 512 tokens
# ⚠ Truncated from 976 to 512 tokens
# ⚠ Truncated from 1144 to 512 tokens
# ⚠ Truncated from 1104 to 512 tokens
# ⚠ Truncated from 916 to 512 tokens
# ⚠ Truncated from 533 to 512 tokens
# ⚠ Truncated from 1385 to 512 tokens
# ⚠ Truncated from 1321 to 512 tokens
# ⚠ Truncated from 1226 to 512 tokens
# ⚠ Truncated from 751 to 512 tokens
# ⚠ Truncated from 1074 to 512 tokens
# ⚠ Truncated from 2992 to 512 tokens
# ⚠ Truncated from 1616 to 512 tokens
# ⚠ Truncated from 765 to 512 tokens
# ⚠ Truncated from 1011 to 512 tokens
# ⚠ Truncated from 2587 to 512 tokens
# ⚠ Truncated from 1130 to 512 tokens
# ⚠ Truncated from 1449 to 512 tokens
# ⚠ Truncated from 854 to 512 tokens
# ⚠ Truncated from 1327 to 512 tokens
# ⚠ Truncated from 909 to 512 tokens
# ⚠ Truncated from 930 to 512 tokens
# ⚠ Truncated from 1463 to 512 tokens
# ⚠ Truncated from 1097 to 512 tokens
# ⚠ Truncated from 1007 to 512 tokens
# ⚠ Truncated from 721 to 512 tokens
# ⚠ Truncated from 867 to 512 tokens
# ⚠ Truncated from 885 to 512 tokens
# ⚠ Truncated from 1349 to 512 tokens
# ⚠ Truncated from 547 to 512 tokens
# ⚠ Truncated from 924 to 512 tokens
# ⚠ Truncated from 564 to 512 tokens
# ⚠ Truncated from 860 to 512 tokens
# ⚠ Truncated from 576 to 512 tokens
# ⚠ Truncated from 759 to 512 tokens
# ⚠ Truncated from 590 to 512 tokens
# ⚠ Truncated from 592 to 512 tokens
# ⚠ Truncated from 1305 to 512 tokens
# ⚠ Truncated from 1330 to 512 tokens
# ⚠ Truncated from 970 to 512 tokens
# ⚠ Truncated from 1077 to 512 tokens
# ⚠ Truncated from 1585 to 512 tokens
# ⚠ Truncated from 1413 to 512 tokens
# ⚠ Truncated from 570 to 512 tokens
# ⚠ Truncated from 555 to 512 tokens
# ⚠ Truncated from 600 to 512 tokens
# ⚠ Truncated from 973 to 512 tokens
# ⚠ Truncated from 683 to 512 tokens
# ⚠ Truncated from 859 to 512 tokens
# ⚠ Truncated from 1179 to 512 tokens
# ⚠ Truncated from 930 to 512 tokens
# ⚠ Truncated from 1090 to 512 tokens
# ⚠ Truncated from 720 to 512 tokens
# ⚠ Truncated from 1249 to 512 tokens
# ⚠ Truncated from 1134 to 512 tokens
# ⚠ Truncated from 762 to 512 tokens
# ⚠ Truncated from 935 to 512 tokens
# ⚠ Truncated from 973 to 512 tokens
# ⚠ Truncated from 825 to 512 tokens
# ⚠ Truncated from 1041 to 512 tokens
# ⚠ Truncated from 795 to 512 tokens
# ⚠ Truncated from 1303 to 512 tokens
# ⚠ Truncated from 666 to 512 tokens
# ⚠ Truncated from 1347 to 512 tokens
# ⚠ Truncated from 818 to 512 tokens
# ⚠ Truncated from 796 to 512 tokens
# ⚠ Truncated from 837 to 512 tokens
# ⚠ Truncated from 735 to 512 tokens
# ⚠ Truncated from 1038 to 512 tokens
# ⚠ Truncated from 911 to 512 tokens
# ⚠ Truncated from 743 to 512 tokens
# ⚠ Truncated from 620 to 512 tokens
# ⚠ Truncated from 632 to 512 tokens
# ⚠ Truncated from 826 to 512 tokens
# ⚠ Truncated from 1069 to 512 tokens
# ⚠ Truncated from 1362 to 512 tokens
# ⚠ Truncated from 963 to 512 tokens
# ⚠ Truncated from 1004 to 512 tokens
# ⚠ Truncated from 739 to 512 tokens
# ⚠ Truncated from 1019 to 512 tokens
# ⚠ Truncated from 528 to 512 tokens
# ⚠ Truncated from 1268 to 512 tokens
# ⚠ Truncated from 1173 to 512 tokens
# ⚠ Truncated from 957 to 512 tokens
# ⚠ Truncated from 722 to 512 tokens
# ⚠ Truncated from 1128 to 512 tokens
# ⚠ Truncated from 1242 to 512 tokens
# ⚠ Truncated from 565 to 512 tokens
# ⚠ Truncated from 883 to 512 tokens
# ⚠ Truncated from 949 to 512 tokens
# ⚠ Truncated from 1007 to 512 tokens
# ⚠ Truncated from 1037 to 512 tokens
# ⚠ Truncated from 935 to 512 tokens
# ⚠ Truncated from 1111 to 512 tokens
# ⚠ Truncated from 810 to 512 tokens
# ⚠ Truncated from 835 to 512 tokens
# ⚠ Truncated from 937 to 512 tokens
# ⚠ Truncated from 713 to 512 tokens
# ⚠ Truncated from 747 to 512 tokens
# ⚠ Truncated from 830 to 512 tokens
# ⚠ Truncated from 1198 to 512 tokens
# ⚠ Truncated from 1193 to 512 tokens
# ⚠ Truncated from 691 to 512 tokens
# ⚠ Truncated from 993 to 512 tokens
# ⚠ Truncated from 1390 to 512 tokens
# ⚠ Truncated from 1136 to 512 tokens
# ⚠ Truncated from 632 to 512 tokens
# ⚠ Truncated from 619 to 512 tokens
# ⚠ Truncated from 914 to 512 tokens
# ⚠ Truncated from 2221 to 512 tokens
# ⚠ Truncated from 739 to 512 tokens
# ⚠ Truncated from 903 to 512 tokens
# ⚠ Truncated from 1229 to 512 tokens
# ⚠ Truncated from 650 to 512 tokens
# ⚠ Truncated from 797 to 512 tokens
# ⚠ Truncated from 765 to 512 tokens
# ⚠ Truncated from 873 to 512 tokens
# ⚠ Truncated from 2321 to 512 tokens
# ⚠ Truncated from 1125 to 512 tokens
# ⚠ Truncated from 680 to 512 tokens
# ⚠ Truncated from 902 to 512 tokens
# ⚠ Truncated from 1106 to 512 tokens
# ⚠ Truncated from 814 to 512 tokens
# ⚠ Truncated from 813 to 512 tokens
# ⚠ Truncated from 1138 to 512 tokens
# ⚠ Truncated from 1157 to 512 tokens
# ⚠ Truncated from 1337 to 512 tokens
# ⚠ Truncated from 601 to 512 tokens
# ⚠ Truncated from 1258 to 512 tokens
# ⚠ Truncated from 1555 to 512 tokens
# ⚠ Truncated from 1260 to 512 tokens
# ⚠ Truncated from 855 to 512 tokens
# ⚠ Truncated from 3230 to 512 tokens
# ⚠ Truncated from 541 to 512 tokens
# ⚠ Truncated from 522 to 512 tokens
# ⚠ Truncated from 877 to 512 tokens
# ⚠ Truncated from 850 to 512 tokens
# ⚠ Truncated from 1190 to 512 tokens
# ⚠ Truncated from 599 to 512 tokens
# ⚠ Truncated from 539 to 512 tokens
# ⚠ Truncated from 1246 to 512 tokens
# ⚠ Truncated from 777 to 512 tokens
# ⚠ Truncated from 531 to 512 tokens
# ⚠ Truncated from 613 to 512 tokens
# ⚠ Truncated from 734 to 512 tokens
# ⚠ Truncated from 1299 to 512 tokens
# ⚠ Truncated from 1018 to 512 tokens
# ⚠ Truncated from 834 to 512 tokens
# ⚠ Truncated from 759 to 512 tokens
# ⚠ Truncated from 721 to 512 tokens
# ⚠ Truncated from 765 to 512 tokens
# ⚠ Truncated from 513 to 512 tokens
# ⚠ Truncated from 854 to 512 tokens
# ⚠ Truncated from 1094 to 512 tokens
# ⚠ Truncated from 833 to 512 tokens
# ⚠ Truncated from 1838 to 512 tokens
# ⚠ Truncated from 940 to 512 tokens
# ⚠ Truncated from 1175 to 512 tokens
# ⚠ Truncated from 662 to 512 tokens
# ⚠ Truncated from 682 to 512 tokens
# ⚠ Truncated from 926 to 512 tokens
# ⚠ Truncated from 892 to 512 tokens
# ⚠ Truncated from 681 to 512 tokens
# ⚠ Truncated from 637 to 512 tokens
# ⚠ Truncated from 848 to 512 tokens
# ⚠ Truncated from 586 to 512 tokens
# ⚠ Truncated from 1095 to 512 tokens
# ⚠ Truncated from 883 to 512 tokens
# ⚠ Truncated from 1126 to 512 tokens
# ⚠ Truncated from 1218 to 512 tokens
# ⚠ Truncated from 658 to 512 tokens
# ⚠ Truncated from 728 to 512 tokens
# ⚠ Truncated from 520 to 512 tokens
# ⚠ Truncated from 979 to 512 tokens
# ⚠ Truncated from 1105 to 512 tokens
# ⚠ Truncated from 521 to 512 tokens
# ⚠ Truncated from 923 to 512 tokens
# ⚠ Truncated from 645 to 512 tokens
# ⚠ Truncated from 1311 to 512 tokens
# ⚠ Truncated from 776 to 512 tokens
# ⚠ Truncated from 1128 to 512 tokens
# ⚠ Truncated from 816 to 512 tokens
# ⚠ Truncated from 1072 to 512 tokens
# ⚠ Truncated from 1070 to 512 tokens
# ⚠ Truncated from 1461 to 512 tokens
# ⚠ Truncated from 1002 to 512 tokens
# ⚠ Truncated from 1167 to 512 tokens
# ⚠ Truncated from 937 to 512 tokens
# ⚠ Truncated from 661 to 512 tokens
# ⚠ Truncated from 1302 to 512 tokens
# ⚠ Truncated from 689 to 512 tokens
# ⚠ Truncated from 602 to 512 tokens
# ⚠ Truncated from 1077 to 512 tokens
# ⚠ Truncated from 1015 to 512 tokens
# ⚠ Truncated from 815 to 512 tokens
# ⚠ Truncated from 892 to 512 tokens
# ⚠ Truncated from 1518 to 512 tokens
# ⚠ Truncated from 1123 to 512 tokens
# ⚠ Truncated from 959 to 512 tokens
# ⚠ Truncated from 832 to 512 tokens
# ⚠ Truncated from 1035 to 512 tokens
# ⚠ Truncated from 819 to 512 tokens
# ⚠ Truncated from 577 to 512 tokens
# ⚠ Truncated from 1463 to 512 tokens
# ⚠ Truncated from 1226 to 512 tokens
# ⚠ Truncated from 1154 to 512 tokens
# ⚠ Truncated from 823 to 512 tokens
# ⚠ Truncated from 997 to 512 tokens
# ⚠ Truncated from 1764 to 512 tokens
# ⚠ Truncated from 801 to 512 tokens
# ⚠ Truncated from 558 to 512 tokens
# ⚠ Truncated from 627 to 512 tokens
# ⚠ Truncated from 751 to 512 tokens
# ⚠ Truncated from 824 to 512 tokens
# ⚠ Truncated from 1055 to 512 tokens
# ⚠ Truncated from 1167 to 512 tokens
# ⚠ Truncated from 677 to 512 tokens
# ⚠ Truncated from 1213 to 512 tokens
# ⚠ Truncated from 718 to 512 tokens
# ⚠ Truncated from 682 to 512 tokens
# ⚠ Truncated from 1368 to 512 tokens
# ⚠ Truncated from 515 to 512 tokens
# ⚠ Truncated from 1000 to 512 tokens
# ⚠ Truncated from 703 to 512 tokens
# ⚠ Truncated from 861 to 512 tokens
# ⚠ Truncated from 1251 to 512 tokens
# ⚠ Truncated from 1747 to 512 tokens
# ⚠ Truncated from 1435 to 512 tokens
# ⚠ Truncated from 934 to 512 tokens
# ⚠ Truncated from 1204 to 512 tokens
# ⚠ Truncated from 583 to 512 tokens
# ⚠ Truncated from 1437 to 512 tokens
# ⚠ Truncated from 2345 to 512 tokens
# ⚠ Truncated from 2366 to 512 tokens
# ⚠ Truncated from 4909 to 512 tokens
# ⚠ Truncated from 741 to 512 tokens
# ⚠ Truncated from 876 to 512 tokens
# ⚠ Truncated from 1283 to 512 tokens
# ⚠ Truncated from 1338 to 512 tokens
# ⚠ Truncated from 727 to 512 tokens
# ⚠ Truncated from 784 to 512 tokens
# ⚠ Truncated from 751 to 512 tokens
# ⚠ Truncated from 1447 to 512 tokens
# ⚠ Truncated from 725 to 512 tokens
# ⚠ Truncated from 989 to 512 tokens
# ⚠ Truncated from 1243 to 512 tokens
# ⚠ Truncated from 857 to 512 tokens
# ⚠ Truncated from 1147 to 512 tokens
# ⚠ Truncated from 1107 to 512 tokens
# ⚠ Truncated from 1380 to 512 tokens
# ⚠ Truncated from 1203 to 512 tokens
# ⚠ Truncated from 1005 to 512 tokens
# ⚠ Truncated from 708 to 512 tokens
# ⚠ Truncated from 1167 to 512 tokens
# ⚠ Truncated from 1469 to 512 tokens
# ⚠ Truncated from 930 to 512 tokens
# ⚠ Truncated from 553 to 512 tokens
# ⚠ Truncated from 801 to 512 tokens
# ⚠ Truncated from 659 to 512 tokens
# ⚠ Truncated from 1176 to 512 tokens
# ⚠ Truncated from 1604 to 512 tokens
# ⚠ Truncated from 780 to 512 tokens
# ⚠ Truncated from 1194 to 512 tokens
# ⚠ Truncated from 1105 to 512 tokens
# ⚠ Truncated from 706 to 512 tokens
# ⚠ Truncated from 995 to 512 tokens
# ⚠ Truncated from 1086 to 512 tokens
# ⚠ Truncated from 1145 to 512 tokens
# ⚠ Truncated from 1410 to 512 tokens
# ⚠ Truncated from 664 to 512 tokens
# ⚠ Truncated from 847 to 512 tokens
# ⚠ Truncated from 676 to 512 tokens
# ⚠ Truncated from 621 to 512 tokens
# ⚠ Truncated from 2552 to 512 tokens
# ⚠ Truncated from 1274 to 512 tokens
# ⚠ Truncated from 996 to 512 tokens
# ⚠ Truncated from 898 to 512 tokens
# ⚠ Truncated from 1208 to 512 tokens
# ⚠ Truncated from 757 to 512 tokens
# ⚠ Truncated from 1091 to 512 tokens
# ⚠ Truncated from 1193 to 512 tokens
# ⚠ Truncated from 627 to 512 tokens
# ⚠ Truncated from 576 to 512 tokens
# ⚠ Truncated from 1235 to 512 tokens
# ⚠ Truncated from 741 to 512 tokens
# ⚠ Truncated from 848 to 512 tokens
# ⚠ Truncated from 635 to 512 tokens
# ⚠ Truncated from 713 to 512 tokens
# ⚠ Truncated from 960 to 512 tokens
# ⚠ Truncated from 1439 to 512 tokens
# ⚠ Truncated from 1252 to 512 tokens
# ⚠ Truncated from 1193 to 512 tokens
# ⚠ Truncated from 952 to 512 tokens
# ⚠ Truncated from 1227 to 512 tokens
# ⚠ Truncated from 1402 to 512 tokens
# ⚠ Truncated from 558 to 512 tokens
# ⚠ Truncated from 951 to 512 tokens
# ⚠ Truncated from 2890 to 512 tokens
# ⚠ Truncated from 1257 to 512 tokens
# ⚠ Truncated from 1172 to 512 tokens
# ⚠ Truncated from 1597 to 512 tokens
# ⚠ Truncated from 1241 to 512 tokens
# ⚠ Truncated from 539 to 512 tokens
# ⚠ Truncated from 526 to 512 tokens
# ⚠ Truncated from 832 to 512 tokens
# ⚠ Truncated from 837 to 512 tokens
# ⚠ Truncated from 868 to 512 tokens
# ⚠ Truncated from 1184 to 512 tokens
# ⚠ Truncated from 1017 to 512 tokens
# ⚠ Truncated from 647 to 512 tokens
# ⚠ Truncated from 673 to 512 tokens
# ⚠ Truncated from 1182 to 512 tokens
# ⚠ Truncated from 1095 to 512 tokens
# ⚠ Truncated from 1340 to 512 tokens
# ⚠ Truncated from 970 to 512 tokens
# ⚠ Truncated from 818 to 512 tokens
# ⚠ Truncated from 614 to 512 tokens
# ⚠ Truncated from 863 to 512 tokens
# ⚠ Truncated from 1142 to 512 tokens
# ⚠ Truncated from 587 to 512 tokens
# ⚠ Truncated from 935 to 512 tokens
# ⚠ Truncated from 672 to 512 tokens
# ⚠ Truncated from 957 to 512 tokens
# ⚠ Truncated from 1033 to 512 tokens
# ⚠ Truncated from 926 to 512 tokens
# ⚠ Truncated from 1008 to 512 tokens
# ⚠ Truncated from 969 to 512 tokens
# ⚠ Truncated from 981 to 512 tokens
# ⚠ Truncated from 983 to 512 tokens
# ⚠ Truncated from 988 to 512 tokens
# ⚠ Truncated from 1204 to 512 tokens
# ⚠ Truncated from 868 to 512 tokens
# ⚠ Truncated from 663 to 512 tokens
# ⚠ Truncated from 857 to 512 tokens
# ⚠ Truncated from 1142 to 512 tokens
# ⚠ Truncated from 1962 to 512 tokens
# ⚠ Truncated from 662 to 512 tokens
# ⚠ Truncated from 1265 to 512 tokens
# ⚠ Truncated from 933 to 512 tokens
# ⚠ Truncated from 777 to 512 tokens
# ⚠ Truncated from 771 to 512 tokens
# ⚠ Truncated from 943 to 512 tokens
# ⚠ Truncated from 1274 to 512 tokens
# ⚠ Truncated from 1417 to 512 tokens
# ⚠ Truncated from 860 to 512 tokens
# ⚠ Truncated from 842 to 512 tokens
# ⚠ Truncated from 565 to 512 tokens
# ⚠ Truncated from 896 to 512 tokens
# ⚠ Truncated from 1351 to 512 tokens
# ⚠ Truncated from 744 to 512 tokens
# ⚠ Truncated from 3386 to 512 tokens
# ⚠ Truncated from 863 to 512 tokens
# ⚠ Truncated from 861 to 512 tokens
# ⚠ Truncated from 954 to 512 tokens
# ⚠ Truncated from 799 to 512 tokens
# ⚠ Truncated from 1048 to 512 tokens
# ⚠ Truncated from 1439 to 512 tokens
# ⚠ Truncated from 1452 to 512 tokens
# ⚠ Truncated from 1512 to 512 tokens
# ⚠ Truncated from 742 to 512 tokens
# ⚠ Truncated from 1355 to 512 tokens
# ⚠ Truncated from 949 to 512 tokens
# ⚠ Truncated from 654 to 512 tokens
# ⚠ Truncated from 574 to 512 tokens
# ⚠ Truncated from 2149 to 512 tokens
# ...
# ⚠ Truncated from 1092 to 512 tokens
# ⚠ Truncated from 668 to 512 tokens
# ⚠ Truncated from 1027 to 512 tokens
# ⚠ Truncated from 847 to 512 tokens
# ⚠ Truncated from 948 to 512 tokens
# ⚠ Truncated from 1297 to 512 tokens
# ⚠ Truncated from 1090 to 512 tokens
# ⚠ Truncated from 1036 to 512 tokens
# ⚠ Truncated from 620 to 512 tokens
# ⚠ Truncated from 615 to 512 tokens
# ⚠ Truncated from 551 to 512 tokens
# ⚠ Truncated from 786 to 512 tokens
# ⚠ Truncated from 1787 to 512 tokens
# ⚠ Truncated from 967 to 512 tokens
# ⚠ Truncated from 857 to 512 tokens
# ⚠ Truncated from 970 to 512 tokens
# ⚠ Truncated from 804 to 512 tokens
# ⚠ Truncated from 534 to 512 tokens
# ⚠ Truncated from 926 to 512 tokens
# ⚠ Truncated from 1192 to 512 tokens
# ⚠ Truncated from 713 to 512 tokens
# ⚠ Truncated from 850 to 512 tokens
# ⚠ Truncated from 657 to 512 tokens
# ⚠ Truncated from 842 to 512 tokens
# ⚠ Truncated from 742 to 512 tokens
# ⚠ Truncated from 566 to 512 tokens
# ⚠ Truncated from 1085 to 512 tokens
# ⚠ Truncated from 1590 to 512 tokens
# ⚠ Truncated from 884 to 512 tokens
# ⚠ Truncated from 1502 to 512 tokens
# ⚠ Truncated from 991 to 512 tokens
# ⚠ Truncated from 1026 to 512 tokens
# ⚠ Truncated from 1167 to 512 tokens
# ⚠ Truncated from 899 to 512 tokens
# ⚠ Truncated from 1420 to 512 tokens
# ⚠ Truncated from 828 to 512 tokens
# ⚠ Truncated from 1547 to 512 tokens
# ⚠ Truncated from 563 to 512 tokens
# ⚠ Truncated from 599 to 512 tokens
# ⚠ Truncated from 1083 to 512 tokens
# ⚠ Truncated from 1279 to 512 tokens
# ⚠ Truncated from 1724 to 512 tokens
# ⚠ Truncated from 776 to 512 tokens
# ⚠ Truncated from 619 to 512 tokens
# ⚠ Truncated from 1459 to 512 tokens
# ⚠ Truncated from 1105 to 512 tokens
# ⚠ Truncated from 599 to 512 tokens
# ⚠ Truncated from 548 to 512 tokens
# ⚠ Truncated from 753 to 512 tokens
# ⚠ Truncated from 1105 to 512 tokens
# ⚠ Truncated from 1345 to 512 tokens
# ⚠ Truncated from 1039 to 512 tokens
# ⚠ Truncated from 974 to 512 tokens
# ⚠ Truncated from 665 to 512 tokens
# ⚠ Truncated from 1066 to 512 tokens
# ⚠ Truncated from 702 to 512 tokens
# ⚠ Truncated from 886 to 512 tokens
# ⚠ Truncated from 636 to 512 tokens
# ⚠ Truncated from 1181 to 512 tokens
# ⚠ Truncated from 517 to 512 tokens
# ⚠ Truncated from 955 to 512 tokens
# ⚠ Truncated from 548 to 512 tokens
# ⚠ Truncated from 668 to 512 tokens
# ⚠ Truncated from 852 to 512 tokens
# ⚠ Truncated from 1390 to 512 tokens
# ⚠ Truncated from 673 to 512 tokens
# ⚠ Truncated from 1293 to 512 tokens
# ⚠ Truncated from 1059 to 512 tokens
# ⚠ Truncated from 1025 to 512 tokens
# ⚠ Truncated from 879 to 512 tokens
# ⚠ Truncated from 983 to 512 tokens
# ⚠ Truncated from 713 to 512 tokens
# ⚠ Truncated from 1488 to 512 tokens
# ⚠ Truncated from 1112 to 512 tokens
# ⚠ Truncated from 573 to 512 tokens
# ⚠ Truncated from 864 to 512 tokens
# ⚠ Truncated from 632 to 512 tokens
# ⚠ Truncated from 657 to 512 tokens
# ⚠ Truncated from 903 to 512 tokens
# ⚠ Truncated from 745 to 512 tokens
# ⚠ Truncated from 1278 to 512 tokens
# ⚠ Truncated from 701 to 512 tokens
# ⚠ Truncated from 673 to 512 tokens
# ⚠ Truncated from 940 to 512 tokens
# ⚠ Truncated from 1924 to 512 tokens
# ⚠ Truncated from 1224 to 512 tokens
# ⚠ Truncated from 1206 to 512 tokens
# ⚠ Truncated from 814 to 512 tokens
# ⚠ Truncated from 874 to 512 tokens
# ⚠ Truncated from 1254 to 512 tokens
# ⚠ Truncated from 712 to 512 tokens
# ⚠ Truncated from 668 to 512 tokens
# ⚠ Truncated from 768 to 512 tokens
# ⚠ Truncated from 985 to 512 tokens
# ⚠ Truncated from 1355 to 512 tokens
# ⚠ Truncated from 1068 to 512 tokens
# ⚠ Truncated from 534 to 512 tokens
# ⚠ Truncated from 832 to 512 tokens
# ⚠ Truncated from 1226 to 512 tokens
# ⚠ Truncated from 986 to 512 tokens
# ⚠ Truncated from 1820 to 512 tokens
# ⚠ Truncated from 579 to 512 tokens
# ⚠ Truncated from 1343 to 512 tokens
# ⚠ Truncated from 1300 to 512 tokens
# ⚠ Truncated from 657 to 512 tokens
# ⚠ Truncated from 700 to 512 tokens
# ⚠ Truncated from 1061 to 512 tokens
# ⚠ Truncated from 848 to 512 tokens
# ⚠ Truncated from 1124 to 512 tokens
# ⚠ Truncated from 776 to 512 tokens
# ⚠ Truncated from 871 to 512 tokens
# ⚠ Truncated from 599 to 512 tokens
# ⚠ Truncated from 791 to 512 tokens
# ⚠ Truncated from 710 to 512 tokens
# ⚠ Truncated from 1409 to 512 tokens
# ⚠ Truncated from 1235 to 512 tokens
# ⚠ Truncated from 1393 to 512 tokens
# ⚠ Truncated from 1381 to 512 tokens
# ⚠ Truncated from 2063 to 512 tokens
# ⚠ Truncated from 762 to 512 tokens
# ⚠ Truncated from 1086 to 512 tokens
# ⚠ Truncated from 940 to 512 tokens
# ⚠ Truncated from 804 to 512 tokens
# ⚠ Truncated from 1211 to 512 tokens
# ⚠ Truncated from 2691 to 512 tokens
# ⚠ Truncated from 1136 to 512 tokens
# ⚠ Truncated from 1389 to 512 tokens
# ⚠ Truncated from 619 to 512 tokens
# ⚠ Truncated from 642 to 512 tokens
# ⚠ Truncated from 1195 to 512 tokens
# ⚠ Truncated from 532 to 512 tokens
# ⚠ Truncated from 2763 to 512 tokens
# ⚠ Truncated from 793 to 512 tokens
# ⚠ Truncated from 1442 to 512 tokens
# ⚠ Truncated from 801 to 512 tokens
# ⚠ Truncated from 928 to 512 tokens
# ⚠ Truncated from 765 to 512 tokens
# ⚠ Truncated from 650 to 512 tokens
# ⚠ Truncated from 1592 to 512 tokens
# ⚠ Truncated from 992 to 512 tokens
# ⚠ Truncated from 823 to 512 tokens
# ⚠ Truncated from 748 to 512 tokens
# ⚠ Truncated from 560 to 512 tokens
# ⚠ Truncated from 573 to 512 tokens
# ⚠ Truncated from 1726 to 512 tokens
# ⚠ Truncated from 839 to 512 tokens
# ⚠ Truncated from 1071 to 512 tokens
# ⚠ Truncated from 652 to 512 tokens
# ⚠ Truncated from 826 to 512 tokens
# ⚠ Truncated from 585 to 512 tokens
# ⚠ Truncated from 718 to 512 tokens
# ⚠ Truncated from 1276 to 512 tokens
# ⚠ Truncated from 922 to 512 tokens
# ⚠ Truncated from 1034 to 512 tokens
# ⚠ Truncated from 546 to 512 tokens
# ⚠ Truncated from 784 to 512 tokens
# ⚠ Truncated from 679 to 512 tokens
# ⚠ Truncated from 792 to 512 tokens
# ⚠ Truncated from 1199 to 512 tokens
# ⚠ Truncated from 1651 to 512 tokens
# ⚠ Truncated from 839 to 512 tokens
# ⚠ Truncated from 1199 to 512 tokens
# ⚠ Truncated from 607 to 512 tokens
# ⚠ Truncated from 1151 to 512 tokens
# ⚠ Truncated from 956 to 512 tokens
# ⚠ Truncated from 1041 to 512 tokens
# ⚠ Truncated from 1031 to 512 tokens
# ⚠ Truncated from 834 to 512 tokens
# ⚠ Truncated from 1280 to 512 tokens
# ⚠ Truncated from 570 to 512 tokens
# ⚠ Truncated from 1676 to 512 tokens
# ⚠ Truncated from 1020 to 512 tokens
# ⚠ Truncated from 744 to 512 tokens
# ⚠ Truncated from 913 to 512 tokens
# ⚠ Truncated from 1059 to 512 tokens
# ⚠ Truncated from 2322 to 512 tokens
# ⚠ Truncated from 799 to 512 tokens
# ⚠ Truncated from 922 to 512 tokens
# ⚠ Truncated from 841 to 512 tokens
# ⚠ Truncated from 657 to 512 tokens
# ⚠ Truncated from 688 to 512 tokens
# ⚠ Truncated from 1245 to 512 tokens
# ⚠ Truncated from 1382 to 512 tokens
# ⚠ Truncated from 540 to 512 tokens
# ⚠ Truncated from 935 to 512 tokens
# ⚠ Truncated from 627 to 512 tokens
# ⚠ Truncated from 842 to 512 tokens
# ⚠ Truncated from 646 to 512 tokens
# ⚠ Truncated from 785 to 512 tokens
# ⚠ Truncated from 649 to 512 tokens
# ⚠ Truncated from 695 to 512 tokens
# ⚠ Truncated from 748 to 512 tokens
# ⚠ Truncated from 670 to 512 tokens
# ⚠ Truncated from 910 to 512 tokens
# ⚠ Truncated from 935 to 512 tokens
# ⚠ Truncated from 1285 to 512 tokens
# ⚠ Truncated from 1550 to 512 tokens
# ⚠ Truncated from 883 to 512 tokens
# ⚠ Truncated from 870 to 512 tokens
# ⚠ Truncated from 862 to 512 tokens
# ⚠ Truncated from 769 to 512 tokens
# ⚠ Truncated from 812 to 512 tokens
# ⚠ Truncated from 602 to 512 tokens
# ⚠ Truncated from 1018 to 512 tokens
# ⚠ Truncated from 1039 to 512 tokens
# ⚠ Truncated from 781 to 512 tokens
# ⚠ Truncated from 1261 to 512 tokens
# ⚠ Truncated from 634 to 512 tokens
# ⚠ Truncated from 965 to 512 tokens
# ⚠ Truncated from 1793 to 512 tokens
# ⚠ Truncated from 1548 to 512 tokens
# ⚠ Truncated from 937 to 512 tokens
# ⚠ Truncated from 1633 to 512 tokens
# ⚠ Truncated from 759 to 512 tokens
# ⚠ Truncated from 1202 to 512 tokens
# ⚠ Truncated from 917 to 512 tokens
# ⚠ Truncated from 1497 to 512 tokens
# ⚠ Truncated from 1174 to 512 tokens
# ⚠ Truncated from 1294 to 512 tokens
# ⚠ Truncated from 838 to 512 tokens
# ⚠ Truncated from 842 to 512 tokens
# ⚠ Truncated from 715 to 512 tokens
# ⚠ Truncated from 674 to 512 tokens
# ⚠ Truncated from 1463 to 512 tokens
# ⚠ Truncated from 807 to 512 tokens
# ⚠ Truncated from 823 to 512 tokens
# ⚠ Truncated from 758 to 512 tokens
# ⚠ Truncated from 1129 to 512 tokens
# ⚠ Truncated from 1297 to 512 tokens
# ⚠ Truncated from 964 to 512 tokens
# ⚠ Truncated from 912 to 512 tokens
# ⚠ Truncated from 1246 to 512 tokens
# ⚠ Truncated from 881 to 512 tokens
# ⚠ Truncated from 858 to 512 tokens
# ⚠ Truncated from 1093 to 512 tokens
# ⚠ Truncated from 914 to 512 tokens
# ⚠ Truncated from 620 to 512 tokens
# ⚠ Truncated from 589 to 512 tokens
# ⚠ Truncated from 1248 to 512 tokens
# ⚠ Truncated from 732 to 512 tokens
# ⚠ Truncated from 1047 to 512 tokens
# ⚠ Truncated from 834 to 512 tokens
# ⚠ Truncated from 707 to 512 tokens
# ⚠ Truncated from 809 to 512 tokens
# ⚠ Truncated from 888 to 512 tokens
# ⚠ Truncated from 806 to 512 tokens
# ⚠ Truncated from 1160 to 512 tokens
# ⚠ Truncated from 557 to 512 tokens
# ⚠ Truncated from 555 to 512 tokens
# ⚠ Truncated from 1047 to 512 tokens
# ⚠ Truncated from 895 to 512 tokens
# ⚠ Truncated from 779 to 512 tokens
# ⚠ Truncated from 1597 to 512 tokens
# ⚠ Truncated from 632 to 512 tokens
# ⚠ Truncated from 878 to 512 tokens
# ⚠ Truncated from 907 to 512 tokens
# ⚠ Truncated from 841 to 512 tokens
# ⚠ Truncated from 1262 to 512 tokens
# ⚠ Truncated from 1122 to 512 tokens
# ⚠ Truncated from 681 to 512 tokens
# ⚠ Truncated from 905 to 512 tokens
# ⚠ Truncated from 804 to 512 tokens
# ⚠ Truncated from 1036 to 512 tokens
# ⚠ Truncated from 1195 to 512 tokens
# ⚠ Truncated from 831 to 512 tokens
# ⚠ Truncated from 856 to 512 tokens
# ⚠ Truncated from 1532 to 512 tokens
# ⚠ Truncated from 1634 to 512 tokens
# ⚠ Truncated from 900 to 512 tokens
# ⚠ Truncated from 1063 to 512 tokens
# ⚠ Truncated from 976 to 512 tokens
# ⚠ Truncated from 1087 to 512 tokens
# ⚠ Truncated from 901 to 512 tokens
# ⚠ Truncated from 1440 to 512 tokens
# ⚠ Truncated from 1015 to 512 tokens
# ⚠ Truncated from 1192 to 512 tokens
# ⚠ Truncated from 1081 to 512 tokens
# ⚠ Truncated from 1146 to 512 tokens
# ⚠ Truncated from 894 to 512 tokens
# ⚠ Truncated from 542 to 512 tokens
# ⚠ Truncated from 2209 to 512 tokens
# ⚠ Truncated from 809 to 512 tokens
# ⚠ Truncated from 855 to 512 tokens
# ⚠ Truncated from 862 to 512 tokens
# ⚠ Truncated from 1495 to 512 tokens
# ⚠ Truncated from 741 to 512 tokens
# ⚠ Truncated from 1146 to 512 tokens
# ⚠ Truncated from 514 to 512 tokens
# ⚠ Truncated from 982 to 512 tokens
# ⚠ Truncated from 651 to 512 tokens
# ⚠ Truncated from 1556 to 512 tokens
# ⚠ Truncated from 1004 to 512 tokens
# ⚠ Truncated from 903 to 512 tokens
# ⚠ Truncated from 786 to 512 tokens
# ⚠ Truncated from 1450 to 512 tokens
# ⚠ Truncated from 927 to 512 tokens
# ⚠ Truncated from 1001 to 512 tokens
# ⚠ Truncated from 797 to 512 tokens
# ⚠ Truncated from 965 to 512 tokens
# ⚠ Truncated from 1553 to 512 tokens
# ⚠ Truncated from 812 to 512 tokens
# ⚠ Truncated from 1249 to 512 tokens
# ⚠ Truncated from 709 to 512 tokens
# ⚠ Truncated from 1099 to 512 tokens
# ⚠ Truncated from 1183 to 512 tokens
# ⚠ Truncated from 532 to 512 tokens
# ⚠ Truncated from 1054 to 512 tokens
# ⚠ Truncated from 740 to 512 tokens
# ⚠ Truncated from 642 to 512 tokens
# ⚠ Truncated from 799 to 512 tokens
# ⚠ Truncated from 660 to 512 tokens
# ⚠ Truncated from 734 to 512 tokens
# ⚠ Truncated from 1306 to 512 tokens
# ⚠ Truncated from 910 to 512 tokens
# ⚠ Truncated from 1078 to 512 tokens
# ⚠ Truncated from 1012 to 512 tokens
# ⚠ Truncated from 563 to 512 tokens
# ⚠ Truncated from 788 to 512 tokens
# ⚠ Truncated from 951 to 512 tokens
# ⚠ Truncated from 794 to 512 tokens
# ⚠ Truncated from 840 to 512 tokens
# ⚠ Truncated from 1993 to 512 tokens
# ⚠ Truncated from 1251 to 512 tokens
# ⚠ Truncated from 569 to 512 tokens
# ⚠ Truncated from 892 to 512 tokens
# ⚠ Truncated from 1507 to 512 tokens
# ⚠ Truncated from 1005 to 512 tokens
# ⚠ Truncated from 1126 to 512 tokens
# ⚠ Truncated from 1380 to 512 tokens
# ⚠ Truncated from 2357 to 512 tokens
# ⚠ Truncated from 670 to 512 tokens
# ⚠ Truncated from 1071 to 512 tokens
# ⚠ Truncated from 1443 to 512 tokens
# ⚠ Truncated from 1071 to 512 tokens
# ⚠ Truncated from 1544 to 512 tokens
# ⚠ Truncated from 1077 to 512 tokens
# ⚠ Truncated from 1193 to 512 tokens
# ⚠ Truncated from 770 to 512 tokens
# ⚠ Truncated from 686 to 512 tokens
# ⚠ Truncated from 786 to 512 tokens
# ⚠ Truncated from 1053 to 512 tokens
# ⚠ Truncated from 1035 to 512 tokens
# ⚠ Truncated from 756 to 512 tokens
# ⚠ Truncated from 871 to 512 tokens
# ⚠ Truncated from 866 to 512 tokens
# ⚠ Truncated from 2561 to 512 tokens
# ⚠ Truncated from 941 to 512 tokens
# ⚠ Truncated from 1224 to 512 tokens
# ⚠ Truncated from 758 to 512 tokens
# ⚠ Truncated from 1202 to 512 tokens
# ⚠ Truncated from 1187 to 512 tokens
# ⚠ Truncated from 632 to 512 tokens
# ⚠ Truncated from 1248 to 512 tokens
# ⚠ Truncated from 831 to 512 tokens
# ⚠ Truncated from 1025 to 512 tokens
# ⚠ Truncated from 612 to 512 tokens
# ⚠ Truncated from 922 to 512 tokens
# ⚠ Truncated from 1435 to 512 tokens
# ⚠ Truncated from 1131 to 512 tokens
# ⚠ Truncated from 712 to 512 tokens
# ⚠ Truncated from 1298 to 512 tokens
# ⚠ Truncated from 903 to 512 tokens
# ⚠ Truncated from 1200 to 512 tokens
# ⚠ Truncated from 727 to 512 tokens
# ⚠ Truncated from 614 to 512 tokens
# ⚠ Truncated from 1188 to 512 tokens
# ⚠ Truncated from 686 to 512 tokens
# ⚠ Truncated from 1033 to 512 tokens
# ⚠ Truncated from 1044 to 512 tokens
# ⚠ Truncated from 607 to 512 tokens
# ⚠ Truncated from 1078 to 512 tokens
# ⚠ Truncated from 525 to 512 tokens
# ⚠ Truncated from 563 to 512 tokens
# ⚠ Truncated from 1452 to 512 tokens
# ⚠ Truncated from 579 to 512 tokens
# ⚠ Truncated from 636 to 512 tokens
# ⚠ Truncated from 695 to 512 tokens
# ⚠ Truncated from 1389 to 512 tokens
# ⚠ Truncated from 1238 to 512 tokens
# ⚠ Truncated from 1349 to 512 tokens
# ⚠ Truncated from 940 to 512 tokens
# ⚠ Truncated from 965 to 512 tokens
# ⚠ Truncated from 616 to 512 tokens
# ⚠ Truncated from 598 to 512 tokens
# ⚠ Truncated from 603 to 512 tokens
# ⚠ Truncated from 601 to 512 tokens
# ⚠ Truncated from 974 to 512 tokens
# ⚠ Truncated from 850 to 512 tokens
# ⚠ Truncated from 1297 to 512 tokens
# ⚠ Truncated from 1275 to 512 tokens
# ⚠ Truncated from 1159 to 512 tokens
# ⚠ Truncated from 927 to 512 tokens
# ⚠ Truncated from 1106 to 512 tokens
# ⚠ Truncated from 869 to 512 tokens
# ⚠ Truncated from 1601 to 512 tokens
# ⚠ Truncated from 1531 to 512 tokens
# ⚠ Truncated from 1137 to 512 tokens
# ⚠ Truncated from 648 to 512 tokens
# ⚠ Truncated from 827 to 512 tokens
# ⚠ Truncated from 843 to 512 tokens
# ⚠ Truncated from 1105 to 512 tokens
# ⚠ Truncated from 796 to 512 tokens
# ⚠ Truncated from 880 to 512 tokens
# ⚠ Truncated from 763 to 512 tokens
# ⚠ Truncated from 923 to 512 tokens
# ⚠ Truncated from 904 to 512 tokens
# ⚠ Truncated from 1108 to 512 tokens
# ⚠ Truncated from 576 to 512 tokens
# ⚠ Truncated from 1135 to 512 tokens
# ⚠ Truncated from 598 to 512 tokens
# ⚠ Truncated from 1144 to 512 tokens
# ⚠ Truncated from 715 to 512 tokens
# ⚠ Truncated from 996 to 512 tokens
# ⚠ Truncated from 605 to 512 tokens
# ⚠ Truncated from 1279 to 512 tokens
# ⚠ Truncated from 694 to 512 tokens
# ⚠ Truncated from 528 to 512 tokens
# ⚠ Truncated from 908 to 512 tokens
# ⚠ Truncated from 541 to 512 tokens
# ⚠ Truncated from 869 to 512 tokens
# ⚠ Truncated from 736 to 512 tokens
# ⚠ Truncated from 1172 to 512 tokens
# ⚠ Truncated from 879 to 512 tokens
# ⚠ Truncated from 947 to 512 tokens
# ⚠ Truncated from 1568 to 512 tokens
# ⚠ Truncated from 533 to 512 tokens
# ⚠ Truncated from 1122 to 512 tokens
# ⚠ Truncated from 2304 to 512 tokens
# ⚠ Truncated from 747 to 512 tokens
# ⚠ Truncated from 1052 to 512 tokens
# ⚠ Truncated from 836 to 512 tokens
# ⚠ Truncated from 1044 to 512 tokens
# ⚠ Truncated from 763 to 512 tokens
# ⚠ Truncated from 1316 to 512 tokens
# ⚠ Truncated from 611 to 512 tokens
# ⚠ Truncated from 592 to 512 tokens
# ⚠ Truncated from 1309 to 512 tokens
# ⚠ Truncated from 793 to 512 tokens
# ⚠ Truncated from 841 to 512 tokens
# ⚠ Truncated from 1189 to 512 tokens
# ⚠ Truncated from 1366 to 512 tokens
# ⚠ Truncated from 953 to 512 tokens
# ⚠ Truncated from 802 to 512 tokens
# ⚠ Truncated from 1579 to 512 tokens
# ⚠ Truncated from 875 to 512 tokens
# ⚠ Truncated from 1167 to 512 tokens
# ✅ Split 'test' selesai: 19928/20000 baris digunakan.
#
# 📁 Semua file disimpan di: /kaggle/working/One2Set/data
#  - test_src.txt
#  - test_trg.txt
#  - train_src.txt
#  - train_trg.txt
#  - valid_src.txt
#  - valid_trg.txt

# %%
def check_substring_in_file(file_path, expected_substring):
    with open(file_path, 'r', encoding='utf-8') as f:
        lines = f.readlines()

    missing_lines = [i+1 for i, line in enumerate(lines) if expected_substring not in line]
    all_ok = len(missing_lines) == 0

    print(f"File: {file_path}")
    if all_ok:
        print(f"Semua baris mengandung substring '{expected_substring}'")
    else:
        print(f"{len(missing_lines)} baris tidak mengandung substring '{expected_substring}': baris {missing_lines}")
    print("-" * 50)


# Daftar file dan substring yang diharapkan
files_and_substrings = {
    "train_src.txt": "<eos>",
    "train_trg.txt": "<peos>",
    "valid_src.txt": "<eos>",
    "valid_trg.txt": "<peos>",
    "test_src.txt": "<eos>",
    "test_trg.txt": "<peos>",
}

# Jalankan pengecekan untuk setiap file
for file_path, substring in files_and_substrings.items():
    check_substring_in_file('/kaggle/working/One2Set/data/'+file_path, substring)
# Out:
# File: /kaggle/working/One2Set/data/train_src.txt
# ✅ Semua baris mengandung substring '<eos>'
# --------------------------------------------------
# File: /kaggle/working/One2Set/data/train_trg.txt
# ✅ Semua baris mengandung substring '<peos>'
# --------------------------------------------------
# File: /kaggle/working/One2Set/data/valid_src.txt
# ✅ Semua baris mengandung substring '<eos>'
# --------------------------------------------------
# File: /kaggle/working/One2Set/data/valid_trg.txt
# ✅ Semua baris mengandung substring '<peos>'
# --------------------------------------------------
# File: /kaggle/working/One2Set/data/test_src.txt
# ✅ Semua baris mengandung substring '<eos>'
# --------------------------------------------------
# File: /kaggle/working/One2Set/data/test_trg.txt
# ✅ Semua baris mengandung substring '<peos>'
# --------------------------------------------------

# %%
def count_stats(src_path, trg_path):
    import numpy as np

    src_lens = []
    trg_counts = []

    with open(src_path, 'r') as f_src, open(trg_path, 'r') as f_trg:
        for src_line, trg_line in zip(f_src, f_trg):
            src_lens.append(len(src_line.strip().split()))
            trg_counts.append(len(trg_line.strip().split(';')))

    print("Statistik Dataset")
    print(f" - Jumlah data: {len(src_lens)}")
    print(f" - Panjang input rata-rata: {np.mean(src_lens):.2f} tokens")
    print(f" - Panjang input maksimal : {np.max(src_lens)} tokens")
    print(f" - Rata-rata keyphrase    : {np.mean(trg_counts):.2f}")
    print(f" - Maksimal keyphrase     : {np.max(trg_counts)}")

# Contoh penggunaan
count_stats("/kaggle/working/One2Set/data/test_src.txt", "/kaggle/working/One2Set/data/test_trg.txt")
count_stats("/kaggle/working/One2Set/data/train_src.txt", "/kaggle/working/One2Set/data/train_trg.txt")
count_stats("/kaggle/working/One2Set/data/valid_src.txt", "/kaggle/working/One2Set/data/valid_trg.txt")

# with open("data/train_src.txt") as f:
#     for i, line in enumerate(f):
#         if len(line.strip().split()) > 512:
#             print(f"Baris {i} terlalu panjang")
# Out:
# 📝 Statistik Dataset
#  - Jumlah data: 19928
#  - Panjang input rata-rata: 424.34 tokens
#  - Panjang input maksimal : 512 tokens
#  - Rata-rata keyphrase    : 5.20
#  - Maksimal keyphrase     : 11
# 📝 Statistik Dataset
#  - Jumlah data: 29807
#  - Panjang input rata-rata: 444.21 tokens
#  - Panjang input maksimal : 512 tokens
#  - Rata-rata keyphrase    : 5.64
#  - Maksimal keyphrase     : 11
# 📝 Statistik Dataset
#  - Jumlah data: 9937
#  - Panjang input rata-rata: 445.00 tokens
#  - Panjang input maksimal : 512 tokens
#  - Rata-rata keyphrase    : 5.60
#  - Maksimal keyphrase     : 11
